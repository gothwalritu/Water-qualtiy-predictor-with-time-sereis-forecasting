# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#Import data
file_path = './Resources/Lake Sammamish-0611_1_1_1994_to_9_30_2022.csv'
df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')
df.head()
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994  L2704-18       1.0                      0.02
# 1  01/06/1994  L2704-19       5.0                       NaN
# 2  01/06/1994  L2704-20      10.0                      0.02
# 3  01/06/1994  L2704-21      15.0                       NaN
# 4  01/06/1994  L2704-22      20.0                       NaN
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Chlorophyll a (µg/L)  \
# 0                   <MDL                 0.02                   0.1
# 1                          NaN            NaN                   NaN
# 2                   <MDL                 0.02                   NaN
# 3                          NaN            NaN                   NaN
# 4                          NaN            NaN                   NaN
#
#   Chlorophyll a Qualifier*  Chloro MDL (µg/L)  Conductivity (µmhos/cm)  ...  \
# 0                      NaN               0.01                    103.0  ...
# ...

# %%
df.count()
# Out:
# CollectDate                        10618
# SampleNum                          10618
# Depth (m)                          10594
# Ammmonia Nitrogen (mg/L)            2538
# Ammmonia Nitrogen Qualifier*        2199
# AN MDL (mg/L)                       2653
# Chlorophyll a (µg/L)                 625
# Chlorophyll a Qualifier*              67
# Chloro MDL (µg/L)                    630
# Conductivity (µmhos/cm)             8133
# Cond Qualifier*                      445
# Cond MDL (µmhos/cm)                 6020
# Dissolved Oxygen (mg/L)             8052
# DO Qualifier*                        809
# DO MDL (mg/L)                       6014
# Ecoli                                170
# Ecoli Qualifier*                       5
# Fecal Coliform (CFU/100ml)           316
# Fecal Coliform Qualifier*              3
# Nitrate Nitrite (mg/L)              2566
# Nitrate Nitrite Qualifier*           575
# Nitrate Nitrite MDL (mg/L)          2654
# Orthophosphate Phosphate (mg/L)     2473
# ...

# %%
df.dtypes
# Out:
# CollectDate                         object
# SampleNum                           object
# Depth (m)                           object
# Ammmonia Nitrogen (mg/L)           float64
# Ammmonia Nitrogen Qualifier*        object
# AN MDL (mg/L)                      float64
# Chlorophyll a (µg/L)               float64
# Chlorophyll a Qualifier*            object
# Chloro MDL (µg/L)                  float64
# Conductivity (µmhos/cm)            float64
# Cond Qualifier*                     object
# Cond MDL (µmhos/cm)                float64
# Dissolved Oxygen (mg/L)            float64
# DO Qualifier*                       object
# DO MDL (mg/L)                      float64
# Ecoli                              float64
# Ecoli Qualifier*                    object
# Fecal Coliform (CFU/100ml)         float64
# Fecal Coliform Qualifier*           object
# Nitrate Nitrite (mg/L)             float64
# Nitrate Nitrite Qualifier*          object
# Nitrate Nitrite MDL (mg/L)         float64
# ...

# %%
df["CollectDate"] = pd.to_datetime(df["CollectDate"])
df.tail()
# Out:
#       CollectDate  SampleNum  Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 10613  2022-09-13  L80241-38       19.0                       NaN
# 10614  2022-09-13  L80241-39       20.0                       NaN
# 10615  2022-09-13  L80241-40       21.0                       NaN
# 10616  2022-09-13  L80059-47        1.0                       NaN
# 10617  2022-09-13  L80059-52  Composite                       NaN
#
#       Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Chlorophyll a (µg/L)  \
# 10613                          NaN            NaN                   NaN
# 10614                          NaN            NaN                   NaN
# 10615                          NaN            NaN                   NaN
# 10616                         <MDL          0.002                   NaN
# 10617                          NaN            NaN                   1.7
#
#       Chlorophyll a Qualifier*  Chloro MDL (µg/L)  Conductivity (µmhos/cm)  \
# ...

# %%
df_clean = df.drop (['Ammmonia Nitrogen Qualifier*', 'Chlorophyll a Qualifier*', 'Temperature Qualifier*', 'TN Qualifier*', 'TP Qualifier*', 'Total Alkalinity Qualifier*', 'Cond Qualifier*', 'pH Qualifier*', 'Secchi Qualifier*', 'DO Qualifier*', 'Ecoli Qualifier*', 'Fecal Coliform Qualifier*', 'Nitrate Nitrite Qualifier*', 'OP Qualifier*', 'Unnamed: 40', 'SampleNum', 'Depth (m)', 'Chlorophyll a (µg/L)', 'Secchi (m)'], axis=1)
df_clean.head(50)
# Out:
#    CollectDate  Ammmonia Nitrogen (mg/L)  AN MDL (mg/L)  Chloro MDL (µg/L)  \
# 0   1994-01-06                      0.02           0.02               0.01
# 1   1994-01-06                       NaN            NaN                NaN
# 2   1994-01-06                      0.02           0.02                NaN
# 3   1994-01-06                       NaN            NaN                NaN
# 4   1994-01-06                       NaN            NaN                NaN
# 5   1994-01-06                      0.02           0.02                NaN
# 6   1994-01-06                      0.02           0.02               0.01
# 7   1994-02-14                      0.02           0.02               0.01
# 8   1994-02-14                       NaN            NaN                NaN
# 9   1994-02-14                      0.02           0.02                NaN
# 10  1994-02-14                       NaN            NaN                NaN
# ...

# %%
df_clean.dtypes
# Out:
# CollectDate                        datetime64[ns]
# Ammmonia Nitrogen (mg/L)                  float64
# AN MDL (mg/L)                             float64
# Chloro MDL (µg/L)                         float64
# Conductivity (µmhos/cm)                   float64
# Cond MDL (µmhos/cm)                       float64
# Dissolved Oxygen (mg/L)                   float64
# DO MDL (mg/L)                             float64
# Ecoli                                     float64
# Fecal Coliform (CFU/100ml)                float64
# Nitrate Nitrite (mg/L)                    float64
# Nitrate Nitrite MDL (mg/L)                float64
# Orthophosphate Phosphate (mg/L)           float64
# OP MDL (mg/L)                             float64
# pH                                        float64
# Temperature (°C)                          float64
# Total Nitrogen (mg/L)                     float64
# TN MDL (mg/L)                             float64
# Total Phosphorus (mg/L)                   float64
# ...

# %%
df_clean.count()
# Out:
# CollectDate                        10618
# Ammmonia Nitrogen (mg/L)            2538
# AN MDL (mg/L)                       2653
# Chloro MDL (µg/L)                    630
# Conductivity (µmhos/cm)             8133
# Cond MDL (µmhos/cm)                 6020
# Dissolved Oxygen (mg/L)             8052
# DO MDL (mg/L)                       6014
# Ecoli                                170
# Fecal Coliform (CFU/100ml)           316
# Nitrate Nitrite (mg/L)              2566
# Nitrate Nitrite MDL (mg/L)          2654
# Orthophosphate Phosphate (mg/L)     2473
# OP MDL (mg/L)                       2651
# pH                                  8139
# Temperature (°C)                    8155
# Total Nitrogen (mg/L)               2647
# TN MDL (mg/L)                       2647
# Total Phosphorus (mg/L)             2746
# TP MDL (mg/L)                       2763
# Total Alkalinity (mg/L)              384
# Total Alkalinity MDL (mg/L)          388
# Unnamed: 40                            0
# ...

# %% [markdown]
# PH, EC, TDS, TH, calcium, magnesium, iron, fluoride, turbidity
