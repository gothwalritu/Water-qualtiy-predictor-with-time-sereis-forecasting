# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import time

# %%
file_path = "Resources/Lake_Sammamish_0612_1_1_1994_to_9_30_2022.csv"

WQ0612_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

WQ0612_df.head(10)
# Out:
# /var/folders/25/v262f3893210tshrdcyr9ly80000gn/T/ipykernel_23563/1117231833.py:3: DtypeWarning: Columns (2,7,13,15,23,25,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   WQ0612_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994   L2704-5       1.0                      0.02
# 1  01/06/1994   L2704-6       5.0                       NaN
# 2  01/06/1994   L2704-7      10.0                      0.02
# 3  01/06/1994   L2704-8      15.0                       NaN
# 4  01/06/1994   L2704-9      20.0                       NaN
# 5  01/06/1994  L2704-10      25.0                      0.02
# 6  01/06/1994   L2704-5       1.0                      0.02
# 7  02/14/1994   L2938-5       1.0                      0.02
# 8  02/14/1994   L2938-6       5.0                       NaN
# 9  02/14/1994   L2938-7      10.0                      0.02
#
# ...

# %%
WQ0612_df.count()
# Out:
# CollectDate                        19929
# SampleNum                          19929
# Depth (m)                          19908
# Ammmonia Nitrogen (mg/L)            2720
# Ammmonia Nitrogen Qualifier*        2362
# AN MDL (mg/L)                       2872
# Conductivity (µmhos/cm)            17791
# Cond Qualifier*                      993
# Cond MDL (µmhos/cm)                15573
# Dissolved Oxygen (mg/L)            17495
# DO Qualifier*                       2582
# DO MDL (mg/L)                      15559
# Ecoli                                172
# Ecoli Qualifier*                       4
# Fecal Coliform (CFU/100ml)           317
# Fecal Coliform Qualifier*              2
# Nitrate Nitrite (mg/L)              2784
# Nitrate Nitrite Qualifier*           560
# Nitrate Nitrite MDL (mg/L)          2872
# Orthophosphate Phosphate (mg/L)     2711
# OP Qualifier*                       1863
# OP MDL (mg/L)                       2869
# pH                                 17795
# ...

# %%
WQ0612_df.columns
# Out:
# Index(['CollectDate', 'SampleNum', 'Depth (m)', 'Ammmonia Nitrogen (mg/L)',
#        'Ammmonia Nitrogen Qualifier*', 'AN MDL (mg/L)',
#        'Conductivity (µmhos/cm)', 'Cond Qualifier*', 'Cond MDL (µmhos/cm)',
#        'Dissolved Oxygen (mg/L)', 'DO Qualifier*', 'DO MDL (mg/L)', 'Ecoli',
#        'Ecoli Qualifier*', 'Fecal Coliform (CFU/100ml)',
#        'Fecal Coliform Qualifier*', 'Nitrate Nitrite (mg/L)',
#        'Nitrate Nitrite Qualifier*', 'Nitrate Nitrite MDL (mg/L)',
#        'Orthophosphate Phosphate (mg/L)', 'OP Qualifier*', 'OP MDL (mg/L)',
#        'pH', 'pH Qualifier*', 'Temperature (°C)', 'Temperature Qualifier*',
#        'Total Nitrogen (mg/L)', 'TN Qualifier*', 'TN MDL (mg/L)',
#        'Total Phosphorus (mg/L)', 'TP Qualifier*', 'TP MDL (mg/L)',
#        'Total Alkalinity (mg/L)', 'Total Alkalinity Qualifier*',
#        'Total Alkalinity MDL (mg/L)', 'Unnamed: 35'],
#       dtype='object')
