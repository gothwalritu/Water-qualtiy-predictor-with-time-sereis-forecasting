# %% [markdown]
# # Merging all the csv files for lake Sammamish

# %%
import pandas as pd 

df_1 = pd.read_csv("../Resources/0611_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

df_2 = pd.read_csv("../Resources/0612_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

df_3 = pd.read_csv("../Resources/0614_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

df_4 = pd.read_csv("../Resources/0617_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

df_5 = pd.read_csv("../Resources/0622_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

df_6 = pd.read_csv("../Resources/0625_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

df_7 = pd.read_csv("../Resources/M621_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

# %%
# append multiple DataFrames

WQI_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7], ignore_index=True)
print(WQI_df.shape)
WQI_df.head()
# Out:
# (9513, 12)
#   CollectDate  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0  1994-01-06                      0.02                    103.0
# 1  1994-01-06                      0.02                    104.0
# 2  1994-01-06                      0.02                    102.0
# 3  1994-01-06                      0.02                    105.0
# 4  1994-01-06                      0.02                    104.0
#
#    Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# 0                     9.15                         1.0
# 1                     8.98                         1.0
# 2                     9.00                         1.0
# 3                     9.21                         1.0
# 4                     9.20                         1.0
#
#    Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                    0.27                            0.011  7.4
# 1                    0.28                            0.012  7.4
# 2                    0.29                            0.012  7.4
# 3                    0.28                            0.012  7.4
# 4                    0.28                            0.012  7.4
#
#    Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  \
# 0               7.4               0.410000                 0.017000
# 1               7.3               0.416667                 0.019667
# 2               7.3               0.440000                 0.019000
# 3               7.3               0.416667                 0.019667
# 4               7.3               0.416667                 0.019667
#
#           WQI
# 0   94.891147
# 1   98.699450
# 2  101.553997
# 3   98.722325
# 4   98.721299

# %%
# Create the output file (CSV)

output_data_file = "../Resources/Big_lake_Sammamish.csv"

# Export the clean water quality data 

WQI_df.to_csv(output_data_file, index="CollectDate")

# %% [markdown]
# # Preprocessing the Data for Neural Network

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf


#  Import and read the charity_data.csv.
import pandas as pd 
#WQI_df = pd.read_csv("../Resources_Ritu/0611_lake_Sammamish.csv").drop(['Unnamed: 0'],axis=1)

WQI_df.head()
# Out:
#   CollectDate  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0  1994-01-06                      0.02                    103.0
# 1  1994-01-06                      0.02                    104.0
# 2  1994-01-06                      0.02                    102.0
# 3  1994-01-06                      0.02                    105.0
# 4  1994-01-06                      0.02                    104.0
#
#    Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# 0                     9.15                         1.0
# 1                     8.98                         1.0
# 2                     9.00                         1.0
# 3                     9.21                         1.0
# 4                     9.20                         1.0
#
#    Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                    0.27                            0.011  7.4
# 1                    0.28                            0.012  7.4
# 2                    0.29                            0.012  7.4
# 3                    0.28                            0.012  7.4
# 4                    0.28                            0.012  7.4
#
#    Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  \
# 0               7.4               0.410000                 0.017000
# 1               7.3               0.416667                 0.019667
# 2               7.3               0.440000                 0.019000
# 3               7.3               0.416667                 0.019667
# 4               7.3               0.416667                 0.019667
#
#           WQI
# 0   94.891147
# 1   98.699450
# 2  101.553997
# 3   98.722325
# 4   98.721299

# %%
# Data Summary

WQI_df.describe()
# Out:
#        Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# count               9513.000000              9513.000000
# mean                   0.019529               104.770451
# std                    0.019682                 6.294638
# min                    0.010000                80.400000
# 25%                    0.010000               102.000000
# 50%                    0.012833               105.000000
# 75%                    0.020333               108.000000
# max                    0.359000               165.000000
#
#        Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# count              9513.000000                 9513.000000
# mean                  8.794612                    3.175549
# std                   3.179340                    8.541212
# min                   0.000000                    0.000000
# 25%                   8.100000                    0.000000
# 50%                   9.400000                    1.000000
# 75%                  10.713636                    3.000000
# max                 124.400000                  180.000000
#
#        Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)           pH  \
# count             9513.000000                      9513.000000  9513.000000
# mean                 0.250499                         0.004699     7.749050
# std                  0.144454                         0.004703     0.697979
# min                  0.020000                         0.002000     6.100000
# 25%                  0.149333                         0.002000     7.200000
# 50%                  0.246000                         0.002650     7.600000
# 75%                  0.336000                         0.006117     8.300000
# max                  1.020000                         0.129000     9.700000
#
#        Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  \
# count       9513.000000            9513.000000              9513.000000
# mean          12.123462               0.450910                 0.015715
# std            4.751851               0.148650                 0.010067
# min            5.200000               0.050000                 0.005000
# 25%            8.300000               0.359333                 0.009700
# 50%           10.800000               0.436833                 0.013800
# 75%           15.400000               0.528500                 0.018733
# max           25.200000               4.900000                 0.193000
#
#                WQI
# count  9513.000000
# mean     88.783753
# std      43.916247
# min      12.702527
# 25%      58.949820
# 50%      86.358482
# 75%     114.044974
# max     349.975650

# %%
# convert string to datetime
WQI_df["CollectDate"] = pd.to_datetime(WQI_df["CollectDate"])

# %%
# Histogram shows the number of instances that have a given value range. Using jupyter's magic command to specify which backend Matplotlib should use.
# %matplotlib inline
import matplotlib.pyplot as plt
WQI_df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# Visualize the value counts of target variable

WQI_df["WQI"].plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
WQI_df_mean = WQI_df.groupby(["CollectDate"]).mean()
WQI_df_mean.head(20)
# Out:
#              Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# CollectDate
# 1994-01-06                   0.020000               103.961538
# 1994-02-14                   0.020000               104.280769
# 1994-03-08                   0.020000               104.496154
# 1994-03-22                   0.020000               104.957692
# 1994-04-05                   0.020000               103.534615
# 1994-04-19                   0.020000               104.238462
# 1994-05-03                   0.020000               107.957692
# 1994-05-24                   0.020444               113.768254
# 1994-06-07                   0.020000               107.194340
# 1994-07-06                   0.021000               114.437097
# 1994-08-02                   0.020000               110.726829
# 1994-09-07                   0.041629               103.366237
# 1994-10-04                   0.044083               111.058333
# 1994-11-01                   0.091272               111.810526
# 1994-12-07                   0.020000               113.978462
# 1995-01-17                   0.020000                91.550000
# 1995-02-08                   0.020095               109.009524
# 1995-03-07                   0.020000               100.366667
# 1995-04-04                   0.020031               100.140625
# 1995-04-18                   0.020000               105.733333
#
#              Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# CollectDate
# 1994-01-06                  9.138846                    3.384615
# 1994-02-14                 10.704615                    6.884615
# 1994-03-08                 10.938077                    0.653846
# 1994-03-22                 11.738462                    2.576923
# 1994-04-05                 12.773077                    3.384615
# 1994-04-19                 12.351923                    0.961538
# 1994-05-03                 11.314615                    0.115385
# 1994-05-24                 10.394286                    0.714286
# 1994-06-07                  9.422830                    1.886792
# 1994-07-06                  8.767097                    0.532258
# 1994-08-02                  7.902683                    0.048780
# 1994-09-07                  6.616946                    3.322581
# 1994-10-04                  6.411667                    2.194444
# 1994-11-01                  5.587632                    5.105263
# 1994-12-07                  8.917846                    3.076923
# 1995-01-17                 10.535000                    6.700000
# 1995-02-08                 10.930952                    1.333333
# 1995-03-07                 11.313333                    1.952381
# 1995-04-04                 12.369687                    0.875000
# 1995-04-18                 12.111111                    2.629630
#
#              Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)  \
# CollectDate
# 1994-01-06                 0.292179                         0.011353
# 1994-02-14                 0.327179                         0.009404
# 1994-03-08                 0.377115                         0.005288
# 1994-03-22                 0.351538                         0.002359
# 1994-04-05                 0.316506                         0.004715
# 1994-04-19                 0.292167                         0.002000
# 1994-05-03                 0.285513                         0.002000
# 1994-05-24                 0.279272                         0.002000
# 1994-06-07                 0.249138                         0.002000
# 1994-07-06                 0.193938                         0.003207
# 1994-08-02                 0.105024                         0.002559
# 1994-09-07                 0.061532                         0.002213
# 1994-10-04                 0.070931                         0.006433
# 1994-11-01                 0.050175                         0.011046
# 1994-12-07                 0.200840                         0.011794
# 1995-01-17                 0.377767                         0.009752
# 1995-02-08                 0.438968                         0.010446
# 1995-03-07                 0.478992                         0.006301
# 1995-04-04                 0.453849                         0.003703
# 1995-04-18                 0.370914                         0.002000
#
#                    pH  Temperature (°C)  Total Nitrogen (mg/L)  \
# CollectDate
# 1994-01-06   7.396154          7.283333               0.427628
# 1994-02-14   7.373077          6.438462               0.782308
# 1994-03-08   7.523077          7.165385               0.581923
# 1994-03-22   7.953846          7.373077               0.566026
# 1994-04-05   8.415385          8.111538               0.514936
# 1994-04-19   8.769231         10.638462               0.486192
# 1994-05-03   8.503846         11.732051               0.460673
# 1994-05-24   8.284127         14.087302               0.441579
# 1994-06-07   7.805660         13.235849               0.440912
# 1994-07-06   8.064516         15.214516               0.398151
# 1994-08-02   8.207317         16.836585               0.362337
# 1994-09-07   8.250753         16.740645               0.276952
# 1994-10-04   8.038889         15.669444               0.279389
# 1994-11-01   7.065789         11.728947               0.294386
# 1994-12-07   7.173077          8.207692               0.381667
# 1995-01-17   7.620000          6.360000               0.611175
# 1995-02-08   7.814286          7.009524               0.647183
# 1995-03-07   7.514286          7.038095               0.682984
# 1995-04-04   8.312500          9.421875               0.639474
# 1995-04-18   8.407407          9.651852               0.588463
#
#              Total Phosphorus (mg/L)         WQI
# CollectDate
# 1994-01-06                  0.033821  106.640664
# 1994-02-14                  0.035462  118.468342
# 1994-03-08                  0.015936  127.209743
# 1994-03-22                  0.017397  120.007024
# 1994-04-05                  0.011218  107.715162
# 1994-04-19                  0.014571  101.444971
# 1994-05-03                  0.012199   98.633201
# 1994-05-24                  0.015847   97.992202
# 1994-06-07                  0.019503   89.734223
# 1994-07-06                  0.016884   72.656770
# 1994-08-02                  0.014837   44.966472
# 1994-09-07                  0.040941   45.926600
# 1994-10-04                  0.024148   44.403470
# 1994-11-01                  0.040575   57.002897
# 1994-12-07                  0.027737   77.307680
# 1995-01-17                  0.028250  131.134690
# 1995-02-08                  0.029659  150.143271
# 1995-03-07                  0.030032  162.302742
# 1995-04-04                  0.021005  152.208859
# 1995-04-18                  0.014117  125.080436

# %%
import seaborn as sns

# %%
# pip install seaborn

# %%
sns.heatmap(WQI_df_mean.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
# correlation among the features of each features in the data frame.

corr_matrix = WQI_df_mean.corr()
round(corr_matrix,2)
# Out:
#                                  Ammmonia Nitrogen (mg/L)  \
# Ammmonia Nitrogen (mg/L)                             1.00
# Conductivity (µmhos/cm)                              0.17
# Dissolved Oxygen (mg/L)                             -0.48
# Fecal Coliform (CFU/100ml)                           0.11
# Nitrate Nitrite (mg/L)                              -0.32
# Orthophosphate Phosphate (mg/L)                      0.23
# pH                                                  -0.26
# Temperature (°C)                                     0.16
# Total Nitrogen (mg/L)                               -0.28
# Total Phosphorus (mg/L)                              0.39
# WQI                                                 -0.22
#
#                                  Conductivity (µmhos/cm)  \
# Ammmonia Nitrogen (mg/L)                            0.17
# Conductivity (µmhos/cm)                             1.00
# Dissolved Oxygen (mg/L)                            -0.42
# Fecal Coliform (CFU/100ml)                         -0.04
# Nitrate Nitrite (mg/L)                             -0.57
# Orthophosphate Phosphate (mg/L)                    -0.22
# pH                                                  0.00
# Temperature (°C)                                    0.35
# Total Nitrogen (mg/L)                              -0.53
# Total Phosphorus (mg/L)                            -0.13
# WQI                                                -0.57
#
#                                  Dissolved Oxygen (mg/L)  \
# Ammmonia Nitrogen (mg/L)                           -0.48
# Conductivity (µmhos/cm)                            -0.42
# Dissolved Oxygen (mg/L)                             1.00
# Fecal Coliform (CFU/100ml)                         -0.03
# Nitrate Nitrite (mg/L)                              0.75
# Orthophosphate Phosphate (mg/L)                     0.03
# pH                                                  0.27
# Temperature (°C)                                   -0.64
# Total Nitrogen (mg/L)                               0.73
# Total Phosphorus (mg/L)                            -0.01
# WQI                                                 0.72
#
#                                  Fecal Coliform (CFU/100ml)  \
# Ammmonia Nitrogen (mg/L)                               0.11
# Conductivity (µmhos/cm)                               -0.04
# Dissolved Oxygen (mg/L)                               -0.03
# Fecal Coliform (CFU/100ml)                             1.00
# Nitrate Nitrite (mg/L)                                 0.14
# Orthophosphate Phosphate (mg/L)                        0.49
# pH                                                    -0.42
# Temperature (°C)                                      -0.30
# Total Nitrogen (mg/L)                                  0.13
# Total Phosphorus (mg/L)                                0.44
# WQI                                                    0.17
#
#                                  Nitrate Nitrite (mg/L)  \
# Ammmonia Nitrogen (mg/L)                          -0.32
# Conductivity (µmhos/cm)                           -0.57
# Dissolved Oxygen (mg/L)                            0.75
# Fecal Coliform (CFU/100ml)                         0.14
# Nitrate Nitrite (mg/L)                             1.00
# Orthophosphate Phosphate (mg/L)                    0.32
# pH                                                 0.03
# Temperature (°C)                                  -0.62
# Total Nitrogen (mg/L)                              0.96
# Total Phosphorus (mg/L)                            0.21
# WQI                                                0.99
#
#                                  Orthophosphate Phosphate (mg/L)    pH  \
# Ammmonia Nitrogen (mg/L)                                    0.23 -0.26
# Conductivity (µmhos/cm)                                    -0.22  0.00
# Dissolved Oxygen (mg/L)                                     0.03  0.27
# Fecal Coliform (CFU/100ml)                                  0.49 -0.42
# Nitrate Nitrite (mg/L)                                      0.32  0.03
# Orthophosphate Phosphate (mg/L)                             1.00 -0.58
# pH                                                         -0.58  1.00
# Temperature (°C)                                           -0.53  0.38
# Total Nitrogen (mg/L)                                       0.26  0.08
# Total Phosphorus (mg/L)                                     0.63 -0.43
# WQI                                                         0.37 -0.01
#
#                                  Temperature (°C)  Total Nitrogen (mg/L)  \
# Ammmonia Nitrogen (mg/L)                     0.16                  -0.28
# Conductivity (µmhos/cm)                      0.35                  -0.53
# Dissolved Oxygen (mg/L)                     -0.64                   0.73
# Fecal Coliform (CFU/100ml)                  -0.30                   0.13
# Nitrate Nitrite (mg/L)                      -0.62                   0.96
# Orthophosphate Phosphate (mg/L)             -0.53                   0.26
# pH                                           0.38                   0.08
# Temperature (°C)                             1.00                  -0.59
# Total Nitrogen (mg/L)                       -0.59                   1.00
# Total Phosphorus (mg/L)                     -0.41                   0.24
# WQI                                         -0.63                   0.96
#
#                                  Total Phosphorus (mg/L)   WQI
# Ammmonia Nitrogen (mg/L)                            0.39 -0.22
# Conductivity (µmhos/cm)                            -0.13 -0.57
# Dissolved Oxygen (mg/L)                            -0.01  0.72
# Fecal Coliform (CFU/100ml)                          0.44  0.17
# Nitrate Nitrite (mg/L)                              0.21  0.99
# Orthophosphate Phosphate (mg/L)                     0.63  0.37
# pH                                                 -0.43 -0.01
# Temperature (°C)                                   -0.41 -0.63
# Total Nitrogen (mg/L)                               0.24  0.96
# Total Phosphorus (mg/L)                             1.00  0.30
# WQI                                                 0.30  1.00

# %%
# Looking for the correlations between WQI and rest of the features

corr_matrix = WQI_df_mean.corr()

round(corr_matrix["WQI"],2).sort_values(ascending=False)
# Out:
# WQI                                1.00
# Nitrate Nitrite (mg/L)             0.99
# Total Nitrogen (mg/L)              0.96
# Dissolved Oxygen (mg/L)            0.72
# Orthophosphate Phosphate (mg/L)    0.37
# Total Phosphorus (mg/L)            0.30
# Fecal Coliform (CFU/100ml)         0.17
# pH                                -0.01
# Ammmonia Nitrogen (mg/L)          -0.22
# Conductivity (µmhos/cm)           -0.57
# Temperature (°C)                  -0.63
# Name: WQI, dtype: float64

# %%
# Scatter plots for each feature with Water Quality Index "WQI"

fig,axis=plt.subplots(3,3)
axis[0,0].scatter(WQI_df["WQI"],WQI_df["Nitrate Nitrite (mg/L)"], s=1) 
axis[0, 0].set_title('Nitrate Nitrite')
axis[0,1].scatter(WQI_df["WQI"],WQI_df["Total Nitrogen (mg/L)"], s=1)
axis[0, 1].set_title('Total Nitrogen')
axis[0,2].scatter(WQI_df["WQI"],WQI_df["Dissolved Oxygen (mg/L)"], s=1)
axis[0, 2].set_title('Dissolved Oxygen')
axis[1,0].scatter(WQI_df["WQI"],WQI_df["Orthophosphate Phosphate (mg/L)"], s=1)
axis[1,0].set_title('Orthophosphate Phosphate')
axis[1,1].scatter(WQI_df["WQI"],WQI_df["Total Phosphorus (mg/L)"], s=1)
axis[1,1].set_title('Total Phosphorus')
axis[1,2].scatter(WQI_df["WQI"],WQI_df["Fecal Coliform (CFU/100ml)"], s=1)
axis[1,2].set_title('Fecal Coliform')
axis[2,0].scatter(WQI_df["WQI"],WQI_df["pH"], s=1)
axis[2,0].set_title('pH')
axis[2,1].scatter(WQI_df["WQI"],WQI_df["Ammmonia Nitrogen (mg/L)"], s=1)
axis[2,1].set_title('Ammmonia Nitrogen')
axis[2,2].scatter(WQI_df["WQI"],WQI_df["Conductivity (µmhos/cm)"], s=1)
axis[2,2].set_title('Conductivity')
plt.tight_layout()
plt.show()

# %%
WQI_df_mean.plot(kind="scatter", x="Temperature (°C)", y="WQI")
# Out:
# C:\Users\gothw\anaconda3\envs\ul\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Temperature (°C)', ylabel='WQI'>

# %%
WQI_df.dtypes
# Out:
# CollectDate                        datetime64[ns]
# Ammmonia Nitrogen (mg/L)                  float64
# Conductivity (µmhos/cm)                   float64
# Dissolved Oxygen (mg/L)                   float64
# Fecal Coliform (CFU/100ml)                float64
# Nitrate Nitrite (mg/L)                    float64
# Orthophosphate Phosphate (mg/L)           float64
# pH                                        float64
# Temperature (°C)                          float64
# Total Nitrogen (mg/L)                     float64
# Total Phosphorus (mg/L)                   float64
# WQI                                       float64
# dtype: object

# %%
WQI_df_1 = WQI_df.drop(columns=["CollectDate"])
WQI_df_1.head()
# Out:
#    Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  Dissolved Oxygen (mg/L)  \
# 0                      0.02                    103.0                     9.15
# 1                      0.02                    104.0                     8.98
# 2                      0.02                    102.0                     9.00
# 3                      0.02                    105.0                     9.21
# 4                      0.02                    104.0                     9.20
#
#    Fecal Coliform (CFU/100ml)  Nitrate Nitrite (mg/L)  \
# 0                         1.0                    0.27
# 1                         1.0                    0.28
# 2                         1.0                    0.29
# 3                         1.0                    0.28
# 4                         1.0                    0.28
#
#    Orthophosphate Phosphate (mg/L)   pH  Temperature (°C)  \
# 0                            0.011  7.4               7.4
# 1                            0.012  7.4               7.3
# 2                            0.012  7.4               7.3
# 3                            0.012  7.4               7.3
# 4                            0.012  7.4               7.3
#
#    Total Nitrogen (mg/L)  Total Phosphorus (mg/L)         WQI
# 0               0.410000                 0.017000   94.891147
# 1               0.416667                 0.019667   98.699450
# 2               0.440000                 0.019000  101.553997
# 3               0.416667                 0.019667   98.722325
# 4               0.416667                 0.019667   98.721299

# %%
WQI_df_1["WQI"] = round(WQI_df_1["WQI"],2)

# %% [markdown]
# # Compile, Train and Evaluate the Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import sklearn as skl
import tensorflow as tf

# %%
### Sandardization of data ###
from sklearn.preprocessing import StandardScaler

X = WQI_df_1.drop(["WQI"],1).values
y = WQI_df_1["WQI"].values.reshape(-1,1)


# To check the number of shapes
print(X.shape)
print(y.shape)

# To check the first five entries
print(y[:5])
# Out:
# (9513, 10)
# (9513, 1)
# [[ 94.89]
#  [ 98.7 ]
#  [101.55]
#  [ 98.72]
#  [ 98.72]]
# C:\Users\gothw\AppData\Local\Temp\ipykernel_41188\194459523.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = WQI_df_1.drop(["WQI"],1).values

# %%
# Create a StandardScaler instances
scaler_X = skl.preprocessing.StandardScaler()
scaler_y = skl.preprocessing.StandardScaler()

# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)


# Fit the scaler
scaler_X.fit(X_train)
scaler_y.fit(y_train)

# Scale the data
X_train_scaled = scaler_X.transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
# y_train_scaled = scaler_y.transform(y_train)
# y_test_scaled = scaler_y.transform(y_test)
y_train
y_test

print(X_train_scaled.shape)
print(y_train.shape)
print(X_test_scaled.shape)
print(y_test.shape)
# Out:
# (7134, 10)
# (7134, 1)
# (2379, 10)
# (2379, 1)

# %%
# importing the libraries
from keras.models import Sequential
from keras.layers import Dense
 
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = 10
hidden_nodes_layer1 = 30
hidden_nodes_layer2 = 15

model = tf.keras.models.Sequential()

# First hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))


# Second hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
model.add(tf.keras.layers.Dense(units=1, activation="linear"))


# Check the structure of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                330
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 811
# Trainable params: 811
# Non-trainable params: 0
# _________________________________________________________________

# %%
#from keras.optimizers import SGD
#opt = SGD(lr=0.01, momentum=0.9)

# %%
# Compiling the model
#model.compile(loss='mean_squared_error', optimizer="adam", metrics=["mse"])
model.compile(loss='mean_squared_error', optimizer="adam")

# %%
# Fitting the ANN to the Training set
history = model.fit(X_train_scaled,y_train,validation_data=(X_test_scaled, y_test), epochs=100)
# Out:
# Epoch 1/100
# 223/223 [==============================] - 5s 12ms/step - loss: 7864.2041 - val_loss: 3565.1736
# Epoch 2/100
# 223/223 [==============================] - 1s 6ms/step - loss: 1281.4894 - val_loss: 605.3604
# Epoch 3/100
# 223/223 [==============================] - 1s 6ms/step - loss: 561.0269 - val_loss: 411.8665
# Epoch 4/100
# 223/223 [==============================] - 1s 6ms/step - loss: 410.7570 - val_loss: 299.8006
# Epoch 5/100
# 223/223 [==============================] - 2s 7ms/step - loss: 314.7187 - val_loss: 227.3673
# Epoch 6/100
# 223/223 [==============================] - 1s 7ms/step - loss: 243.2537 - val_loss: 175.7566
# Epoch 7/100
# 223/223 [==============================] - 2s 8ms/step - loss: 189.9567 - val_loss: 131.5143
# Epoch 8/100
# 223/223 [==============================] - 2s 8ms/step - loss: 149.4661 - val_loss: 104.2193
# Epoch 9/100
# 223/223 [==============================] - 2s 10ms/step - loss: 116.6059 - val_loss: 76.2701
# Epoch 10/100
# 223/223 [==============================] - 3s 12ms/step - loss: 89.2527 - val_loss: 58.3752
# Epoch 11/100
# 223/223 [==============================] - 2s 9ms/step - loss: 67.9535 - val_loss: 43.1689
# Epoch 12/100
# 223/223 [==============================] - 2s 7ms/step - loss: 50.2473 - val_loss: 31.8462
# Epoch 13/100
# 223/223 [==============================] - 1s 6ms/step - loss: 37.7711 - val_loss: 22.2369
# Epoch 14/100
# 223/223 [==============================] - 1s 7ms/step - loss: 27.8847 - val_loss: 16.5667
# Epoch 15/100
# 223/223 [==============================] - 1s 6ms/step - loss: 20.5456 - val_loss: 11.9267
# Epoch 16/100
# 223/223 [==============================] - 1s 6ms/step - loss: 15.3912 - val_loss: 8.4068
# Epoch 17/100
# 223/223 [==============================] - 1s 6ms/step - loss: 11.4309 - val_loss: 6.4105
# Epoch 18/100
# 223/223 [==============================] - 2s 8ms/step - loss: 8.6499 - val_loss: 4.5594
# Epoch 19/100
# 223/223 [==============================] - 1s 6ms/step - loss: 6.4788 - val_loss: 3.4712
# Epoch 20/100
# 223/223 [==============================] - 1s 5ms/step - loss: 4.9566 - val_loss: 2.9484
# Epoch 21/100
# 223/223 [==============================] - 1s 6ms/step - loss: 3.8612 - val_loss: 2.4063
# Epoch 22/100
# 223/223 [==============================] - 1s 6ms/step - loss: 2.9988 - val_loss: 1.9713
# Epoch 23/100
# 223/223 [==============================] - 1s 6ms/step - loss: 2.3014 - val_loss: 1.6441
# Epoch 24/100
# 223/223 [==============================] - 1s 6ms/step - loss: 1.5785 - val_loss: 1.5112
# Epoch 25/100
# 223/223 [==============================] - 1s 6ms/step - loss: 1.1486 - val_loss: 1.2419
# Epoch 26/100
# 223/223 [==============================] - 1s 6ms/step - loss: 0.8896 - val_loss: 1.1161
# Epoch 27/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.6892 - val_loss: 1.0641
# Epoch 28/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.5552 - val_loss: 0.9469
# Epoch 29/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.4804 - val_loss: 0.8551
# Epoch 30/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.4019 - val_loss: 0.8170
# Epoch 31/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.3514 - val_loss: 0.6696
# Epoch 32/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.3042 - val_loss: 0.6241
# Epoch 33/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.2752 - val_loss: 0.5651
# Epoch 34/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.2370 - val_loss: 0.5407
# Epoch 35/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.2212 - val_loss: 0.4868
# Epoch 36/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.2051 - val_loss: 0.3762
# Epoch 37/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1780 - val_loss: 0.3615
# Epoch 38/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1504 - val_loss: 0.3788
# Epoch 39/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1529 - val_loss: 0.3191
# Epoch 40/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1297 - val_loss: 0.2730
# Epoch 41/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1197 - val_loss: 0.2650
# Epoch 42/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1118 - val_loss: 0.2273
# Epoch 43/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.2466
# Epoch 44/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0904 - val_loss: 0.1959
# Epoch 45/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0918 - val_loss: 0.1690
# Epoch 46/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0841 - val_loss: 0.1816
# Epoch 47/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.2100 - val_loss: 0.2150
# Epoch 48/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1099 - val_loss: 0.1544
# Epoch 49/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1755 - val_loss: 0.6520
# Epoch 50/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.2106 - val_loss: 0.1698
# Epoch 51/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0597 - val_loss: 0.1765
# Epoch 52/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0500 - val_loss: 0.1501
# Epoch 53/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0508 - val_loss: 0.1513
# Epoch 54/100
# 223/223 [==============================] - 1s 3ms/step - loss: 0.0661 - val_loss: 0.1299
# Epoch 55/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0913 - val_loss: 0.7024
# Epoch 56/100
# 223/223 [==============================] - 1s 3ms/step - loss: 0.0732 - val_loss: 0.1490
# Epoch 57/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0846 - val_loss: 0.1632
# Epoch 58/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0847 - val_loss: 0.1596
# Epoch 59/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1173 - val_loss: 0.0982
# Epoch 60/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1126 - val_loss: 0.1456
# Epoch 61/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0636 - val_loss: 0.0958
# Epoch 62/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0575 - val_loss: 0.1586
# Epoch 63/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0572 - val_loss: 0.0975
# Epoch 64/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1201 - val_loss: 0.1752
# Epoch 65/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.2032 - val_loss: 0.1704
# Epoch 66/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1382 - val_loss: 0.2448
# Epoch 67/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1326 - val_loss: 0.2281
# Epoch 68/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0975 - val_loss: 0.2899
# Epoch 69/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.1446 - val_loss: 0.0785
# Epoch 70/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.1008 - val_loss: 0.3967
# Epoch 71/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0616 - val_loss: 0.0883
# Epoch 72/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0437 - val_loss: 0.0888
# Epoch 73/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0286 - val_loss: 0.0768
# Epoch 74/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0342 - val_loss: 0.1446
# Epoch 75/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0429 - val_loss: 0.0679
# Epoch 76/100
# 223/223 [==============================] - 2s 7ms/step - loss: 0.0264 - val_loss: 0.0790
# Epoch 77/100
# 223/223 [==============================] - 1s 6ms/step - loss: 0.0220 - val_loss: 0.0645
# Epoch 78/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0467 - val_loss: 0.1331
# Epoch 79/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0549 - val_loss: 0.4455
# Epoch 80/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.1241 - val_loss: 0.1486
# Epoch 81/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0578 - val_loss: 0.2056
# Epoch 82/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.1648 - val_loss: 0.0761
# Epoch 83/100
# 223/223 [==============================] - 1s 4ms/step - loss: 0.0468 - val_loss: 0.1605
# Epoch 84/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0621 - val_loss: 0.0644
# Epoch 85/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0431 - val_loss: 0.1127
# Epoch 86/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0514 - val_loss: 0.0602
# Epoch 87/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0441 - val_loss: 0.0578
# Epoch 88/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0798 - val_loss: 0.0593
# Epoch 89/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0476 - val_loss: 0.0992
# Epoch 90/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0502
# Epoch 91/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.1061 - val_loss: 0.1173
# Epoch 92/100
# 223/223 [==============================] - 1s 6ms/step - loss: 0.0393 - val_loss: 0.1077
# Epoch 93/100
# 223/223 [==============================] - 2s 7ms/step - loss: 0.0278 - val_loss: 0.0665
# Epoch 94/100
# 223/223 [==============================] - 1s 7ms/step - loss: 0.0966 - val_loss: 0.0980
# Epoch 95/100
# 223/223 [==============================] - 2s 7ms/step - loss: 0.0744 - val_loss: 0.2996
# Epoch 96/100
# 223/223 [==============================] - 1s 6ms/step - loss: 0.2459 - val_loss: 0.0829
# Epoch 97/100
# 223/223 [==============================] - 2s 7ms/step - loss: 0.0711 - val_loss: 0.0741
# Epoch 98/100
# 223/223 [==============================] - 1s 5ms/step - loss: 0.0285 - val_loss: 0.0565
# Epoch 99/100
# 223/223 [==============================] - 1s 6ms/step - loss: 0.0141 - val_loss: 0.0500
# Epoch 100/100
# 223/223 [==============================] - 2s 8ms/step - loss: 0.0248 - val_loss: 0.1644

# %%
# Making predictions using the testing data.
y_pred = model.predict(X_test_scaled)
print(y_pred.shape)
print(y_pred)
# Out:
# 75/75 [==============================] - 1s 4ms/step
# (2379, 1)
# [[ 95.335625]
#  [ 71.236115]
#  [ 99.59065 ]
#  ...
#  [165.0833  ]
#  [ 48.111958]
#  [111.455734]]

# %%
print(y_test)
# Out:
# [[ 94.93]
#  [ 71.04]
#  [ 99.44]
#  ...
#  [164.89]
#  [ 47.9 ]
#  [111.03]]

# %%
y_pred_new = []
for i in y_pred:
    y_pred_new.append(i[0])
    
y_test_new = []
for i in y_test:
    y_test_new.append(i[0])

# %%
import pandas as pd

accuracy_df = pd.DataFrame({"Prediction":y_pred_new, "Actual":y_test_new})
accuracy_df.head(20)
# Out:
#     Prediction  Actual
# 0    95.335625   94.93
# 1    71.236115   71.04
# 2    99.590652   99.44
# 3   212.902679  212.42
# 4   167.064774  166.89
# 5    81.745712   81.42
# 6   183.959167  183.53
# 7    66.896103   66.86
# 8    92.587914   92.20
# 9    98.988754   98.94
# 10   49.980381   50.05
# 11   88.954666   88.83
# 12  106.028053  105.72
# 13   37.047443   36.99
# 14   86.839302   86.72
# 15   91.912567   91.50
# 16   63.006763   62.31
# 17  118.773399  118.67
# 18   42.129490   41.99
# 19   13.593862   13.62

# %%
# evaluate the model
train_mse = model.evaluate(X_train_scaled, y_train, verbose=0)
test_mse = model.evaluate(X_test_scaled,y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_mse, test_mse))
# Out:
# Train: 0.087, Test: 0.164

# %%
from matplotlib import pyplot
#plot loss during training
pyplot.title('Loss / Mean Squared Error')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
#pyplot.plot(history.history['mean_squared_error'], label='mse')
pyplot.legend()
pyplot.show()

# %%
from matplotlib import pyplot
plt.figure(figsize=(10, 5))
plt.title('')
plt.plot(accuracy_df['Actual'], label='Actual values', color='orange', linewidth=5)
plt.plot(accuracy_df['Prediction'], label='Predicted', linewidth=1, linestyle='dashed')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot
plt.title('')
#plt.plot(accuracy_df['Actual'], label='Actual values')
plt.plot(accuracy_df['Prediction'], label='Predicted')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot
plt.title('')
x=accuracy_df['Actual']
y=accuracy_df['Prediction']
plt.scatter(x,y)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
