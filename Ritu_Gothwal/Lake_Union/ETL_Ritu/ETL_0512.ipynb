# %%
# Initial imports
import pandas as pd
from datetime import datetime

# %% [markdown]
# # Import the data

# %%
# Load the water_quality_data.csv dataset for monitoring station 0611.

file_path_1 = "../Raw_Water_Quality_Data/Lake_Union-0512_1_1_1994_to_9_30_2022.csv"
WQ_df = pd.read_csv(file_path_1,skiprows=12, encoding='unicode_escape', on_bad_lines='skip')
WQ_df.head(10)
# Out:
#   CollectDate SampleNum  Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/18/1994   L2782-1  Composite                     0.020
# 1  01/18/1994   L2782-1  Composite                     0.020
# 2  02/22/1994   L2963-1  Composite                     0.042
# 3  02/22/1994   L2963-1  Composite                     0.042
# 4  03/14/1994   L3197-1  Composite                     0.020
# 5  03/14/1994   L3197-1  Composite                     0.020
# 6  04/11/1994   L3418-1  Composite                     0.020
# 7  04/11/1994   L3418-1  Composite                     0.020
# 8  05/16/1994   L3629-1  Composite                     0.020
# 9  05/16/1994   L3629-1  Composite                     0.020
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                 0.02                      NaN
# 1                   <MDL                 0.02                      NaN
# 2                          NaN           0.02                      NaN
# 3                          NaN           0.02                      NaN
# 4                   <MDL                 0.02                      NaN
# 5                   <MDL                 0.02                      NaN
# 6                   <MDL                 0.02                      NaN
# 7                   <MDL                 0.02                      NaN
# 8                   <MDL                 0.02                      NaN
# 9                   <MDL                 0.02                      NaN
#
#   Cond Qualifier*  Cond MDL (µmhos/cm)  Dissolved Oxygen (mg/L)  ...  \
# 0             NaN                  NaN                      NaN  ...
# 1             NaN                  NaN                      NaN  ...
# 2             NaN                  NaN                      NaN  ...
# 3             NaN                  NaN                      NaN  ...
# 4             NaN                  NaN                      NaN  ...
# 5             NaN                  NaN                      NaN  ...
# 6             NaN                  NaN                      NaN  ...
# 7             NaN                  NaN                      NaN  ...
# 8             NaN                  NaN                      NaN  ...
# 9             NaN                  NaN                      NaN  ...
#
#   Total Nitrogen (mg/L)  TN Qualifier*  TN MDL (mg/L) Total Phosphorus (mg/L)  \
# 0                 0.340            NaN           0.05                   0.021
# 1                 0.340            NaN           0.05                   0.021
# 2                 0.310            NaN           0.05                   0.025
# 3                 0.310            NaN           0.05                   0.025
# 4                 0.400            NaN           0.05                   0.028
# 5                 0.400            NaN           0.05                   0.028
# 6                 0.337            NaN           0.05                   0.019
# 7                 0.337            NaN           0.05                   0.019
# 8                 0.248            NaN           0.05                   0.025
# 9                 0.248            NaN           0.05                   0.025
#
#    TP Qualifier* TP MDL (mg/L)  Total Alkalinity (mg/L)  \
# 0            NaN         0.005                      NaN
# 1            NaN         0.005                      NaN
# 2            NaN         0.005                      NaN
# 3            NaN         0.005                      NaN
# 4            NaN         0.005                      NaN
# 5            NaN         0.005                      NaN
# 6            NaN         0.005                      NaN
# 7            NaN         0.005                      NaN
# 8            NaN         0.005                      NaN
# 9            NaN         0.005                      NaN
#
#   Total Alkalinity Qualifier*  Total Alkalinity MDL (mg/L)  Unnamed: 35
# 0                         NaN                          NaN          NaN
# 1                         NaN                          NaN          NaN
# 2                         NaN                          NaN          NaN
# 3                         NaN                          NaN          NaN
# 4                         NaN                          NaN          NaN
# 5                         NaN                          NaN          NaN
# 6                         NaN                          NaN          NaN
# 7                         NaN                          NaN          NaN
# 8                         NaN                          NaN          NaN
# 9                         NaN                          NaN          NaN
#
# [10 rows x 36 columns]

# %%
WQ_df .shape
# Out:
# (2305, 36)

# %%
WQ_df .count()
# Out:
# CollectDate                        2305
# SampleNum                          2305
# Depth (m)                          2284
# Ammmonia Nitrogen (mg/L)           1013
# Ammmonia Nitrogen Qualifier*        634
# AN MDL (mg/L)                      1028
# Conductivity (µmhos/cm)            1365
# Cond Qualifier*                      45
# Cond MDL (µmhos/cm)                1025
# Dissolved Oxygen (mg/L)            1365
# DO Qualifier*                        54
# DO MDL (mg/L)                      1025
# Ecoli                               256
# Ecoli Qualifier*                      4
# Fecal Coliform (CFU/100ml)          632
# Fecal Coliform Qualifier*            42
# Nitrate Nitrite (mg/L)              987
# Nitrate Nitrite Qualifier*          453
# Nitrate Nitrite MDL (mg/L)         1028
# Orthophosphate Phosphate (mg/L)    1021
# OP Qualifier*                       662
# OP MDL (mg/L)                      1028
# pH                                 1433
# pH Qualifier*                        53
# Temperature (°C)                   1452
# Temperature Qualifier*               44
# Total Nitrogen (mg/L)              1004
# TN Qualifier*                        44
# TN MDL (mg/L)                      1004
# Total Phosphorus (mg/L)            1123
# TP Qualifier*                       131
# TP MDL (mg/L)                      1123
# Total Alkalinity (mg/L)             123
# Total Alkalinity Qualifier*           0
# Total Alkalinity MDL (mg/L)         123
# Unnamed: 35                           0
# dtype: int64

# %%
# Dropping the columns which are not very useful for the analysis. 
# df.drop(['col1','col2','col5','colN'], axis=1, inplace=True) 

WQ_df  = WQ_df.drop(columns=["Depth (m)", "Ammmonia Nitrogen Qualifier*", "Cond Qualifier*", "DO Qualifier*", 
                                "Ecoli Qualifier*", "Fecal Coliform Qualifier*","Nitrate Nitrite Qualifier*", "OP Qualifier*", 
                                "pH Qualifier*","Temperature Qualifier*", "TN Qualifier*", "TN Qualifier*","TP Qualifier*", "Total Alkalinity Qualifier*","Unnamed: 35" ])

# Dropping the columns with heading MDL in it as it is just reporting the minimum detection limit of the method, which is not actually usefull for this analysis.
WQ_df = WQ_df.drop(columns=["AN MDL (mg/L)", "Cond MDL (µmhos/cm)", "DO MDL (mg/L)", "Nitrate Nitrite MDL (mg/L)",
                                  "OP MDL (mg/L)", "TN MDL (mg/L)", "TP MDL (mg/L)", "Total Alkalinity MDL (mg/L)" ])

print(WQ_df.shape)
WQ_df.tail()
# Out:
# (2305, 14)
#      CollectDate  SampleNum  Ammmonia Nitrogen (mg/L)  \
# 2300  09/26/2022   L80181-2                       NaN
# 2301  09/26/2022   L80348-3                       NaN
# 2302  09/26/2022   L80348-4                       NaN
# 2303  09/26/2022   L80181-1                       NaN
# 2304  09/26/2022  L80181-39                       NaN
#
#       Conductivity (µmhos/cm)  Dissolved Oxygen (mg/L)  Ecoli  \
# 2300                      NaN                      NaN    NaN
# 2301                    315.0                     8.13    NaN
# 2302                    333.8                     8.13    NaN
# 2303                      NaN                      NaN   16.0
# 2304                      NaN                      NaN   25.0
#
#       Fecal Coliform (CFU/100ml)  Nitrate Nitrite (mg/L)  \
# 2300                         NaN                     NaN
# 2301                         NaN                     NaN
# 2302                         NaN                     NaN
# 2303                        25.0                     NaN
# 2304                        24.0                     NaN
#
#       Orthophosphate Phosphate (mg/L)   pH  Temperature (°C)  \
# 2300                           0.0027  NaN               NaN
# 2301                              NaN  7.4              19.4
# 2302                              NaN  7.4              19.4
# 2303                           0.0024  NaN               NaN
# 2304                           0.0025  NaN               NaN
#
#       Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  Total Alkalinity (mg/L)
# 2300                  0.190                   0.0140                      NaN
# 2301                    NaN                      NaN                      NaN
# 2302                    NaN                      NaN                      NaN
# 2303                  0.191                   0.0158                      NaN
# 2304                  0.184                   0.0151                      NaN

# %%
WQ_df.count()
# Out:
# CollectDate                        2305
# SampleNum                          2305
# Ammmonia Nitrogen (mg/L)           1013
# Conductivity (µmhos/cm)            1365
# Dissolved Oxygen (mg/L)            1365
# Ecoli                               256
# Fecal Coliform (CFU/100ml)          632
# Nitrate Nitrite (mg/L)              987
# Orthophosphate Phosphate (mg/L)    1021
# pH                                 1433
# Temperature (°C)                   1452
# Total Nitrogen (mg/L)              1004
# Total Phosphorus (mg/L)            1123
# Total Alkalinity (mg/L)             123
# dtype: int64

# %%
WQ_df.isnull().sum()
# Out:
# CollectDate                           0
# SampleNum                             0
# Ammmonia Nitrogen (mg/L)           1292
# Conductivity (µmhos/cm)             940
# Dissolved Oxygen (mg/L)             940
# Ecoli                              2049
# Fecal Coliform (CFU/100ml)         1673
# Nitrate Nitrite (mg/L)             1318
# Orthophosphate Phosphate (mg/L)    1284
# pH                                  872
# Temperature (°C)                    853
# Total Nitrogen (mg/L)              1301
# Total Phosphorus (mg/L)            1182
# Total Alkalinity (mg/L)            2182
# dtype: int64

# %%
WQ_df_1 = WQ_df.drop(columns=["Ecoli", "Total Alkalinity (mg/L)"])
print(WQ_df_1.shape)
WQ_df_1.head()
# Out:
# (2305, 12)
#   CollectDate SampleNum  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0  01/18/1994   L2782-1                     0.020                      NaN
# 1  01/18/1994   L2782-1                     0.020                      NaN
# 2  02/22/1994   L2963-1                     0.042                      NaN
# 3  02/22/1994   L2963-1                     0.042                      NaN
# 4  03/14/1994   L3197-1                     0.020                      NaN
#
#    Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# 0                      NaN                       170.0
# 1                      NaN                       170.0
# 2                      NaN                        32.0
# 3                      NaN                        32.0
# 4                      NaN                        32.0
#
#    Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                    0.19                            0.009  6.8
# 1                    0.19                            0.009  6.8
# 2                    0.25                            0.011  7.1
# 3                    0.25                            0.011  7.1
# 4                    0.17                            0.005  7.3
#
#    Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)
# 0               8.0                   0.34                    0.021
# 1               8.0                   0.34                    0.021
# 2               6.3                   0.31                    0.025
# 3               6.3                   0.31                    0.025
# 4               9.0                   0.40                    0.028

# %%
WQ_df_1.dtypes
# Out:
# CollectDate                         object
# SampleNum                           object
# Ammmonia Nitrogen (mg/L)           float64
# Conductivity (µmhos/cm)            float64
# Dissolved Oxygen (mg/L)            float64
# Fecal Coliform (CFU/100ml)         float64
# Nitrate Nitrite (mg/L)             float64
# Orthophosphate Phosphate (mg/L)    float64
# pH                                 float64
# Temperature (°C)                   float64
# Total Nitrogen (mg/L)              float64
# Total Phosphorus (mg/L)            float64
# dtype: object

# %%
# convert string to datetime
WQ_df_1["CollectDate"] = pd.to_datetime(WQ_df_1["CollectDate"])

# convert string to float/numeric
WQ_df_1["pH"] = pd.to_numeric(WQ_df_1["pH"],errors='coerce')

WQ_df_1.dtypes
# Out:
# CollectDate                        datetime64[ns]
# SampleNum                                  object
# Ammmonia Nitrogen (mg/L)                  float64
# Conductivity (µmhos/cm)                   float64
# Dissolved Oxygen (mg/L)                   float64
# Fecal Coliform (CFU/100ml)                float64
# Nitrate Nitrite (mg/L)                    float64
# Orthophosphate Phosphate (mg/L)           float64
# pH                                        float64
# Temperature (°C)                          float64
# Total Nitrogen (mg/L)                     float64
# Total Phosphorus (mg/L)                   float64
# dtype: object

# %%
# Dropping the duplicate Sample in the column "SampleNum"
df_1 = WQ_df_1.drop_duplicates(subset=['SampleNum'])
print(df_1.shape)
df_1.head(50)
# Out:
# (2180, 12)
#    CollectDate SampleNum  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0   1994-01-18   L2782-1                     0.020                      NaN
# 2   1994-02-22   L2963-1                     0.042                      NaN
# 4   1994-03-14   L3197-1                     0.020                      NaN
# 6   1994-04-11   L3418-1                     0.020                      NaN
# 8   1994-05-16   L3629-1                     0.020                      NaN
# 10  1994-06-20   L3895-1                     0.020                      NaN
# 12  1994-07-11   L4044-1                     0.020                      NaN
# 14  1994-08-10   L4249-1                     0.020                      NaN
# 16  1994-09-21   L4488-1                     0.029                      NaN
# 18  1994-10-10   L4668-1                     0.066                      NaN
# 20  1994-11-07   L4869-1                     0.020                      NaN
# 22  1994-12-12   L5052-1                     0.021                      NaN
# 24  1995-01-09   L5174-1                     0.020                      NaN
# 26  1995-02-14   L5351-1                     0.020                      NaN
# 28  1995-03-13   L5618-1                     0.020                      NaN
# 30  1995-04-10   L5809-1                     0.020                      NaN
# 32  1995-05-08   L6046-1                     0.020                      NaN
# 34  1995-06-12   L6194-1                     0.020                      NaN
# 36  1995-07-17   L6493-1                     0.020                      NaN
# 38  1995-08-14   L6655-1                     0.077                      NaN
# 40  1995-09-18   L6821-1                     0.041                      NaN
# 42  1995-10-16   L7073-1                     0.031                      NaN
# 44  1995-11-13   L7316-1                     0.020                      NaN
# 46  1995-12-11   L7400-1                     0.022                      NaN
# 48  1996-01-08   L7585-1                     0.038                      NaN
# 50  1996-02-08   L7849-8                       NaN                      NaN
# 51  1996-02-12   L7788-1                     0.020                      NaN
# 52  1996-02-12   L7883-8                       NaN                      NaN
# 54  1996-02-15   L7905-8                       NaN                      NaN
# 55  1996-02-22   L7966-8                       NaN                      NaN
# 56  1996-02-29   L7998-8                       NaN                      NaN
# 57  1996-03-07   L8027-8                       NaN                      NaN
# 58  1996-03-11   L7987-1                     0.024                      NaN
# 60  1996-03-14   L8090-8                       NaN                      NaN
# 61  1996-03-21   L8145-8                       NaN                      NaN
# 62  1996-03-28   L8168-8                       NaN                      NaN
# 63  1996-04-04   L8221-8                       NaN                      NaN
# 64  1996-04-11   L8255-8                       NaN                      NaN
# 65  1996-04-12   L8288-8                       NaN                      NaN
# 66  1996-04-15   L8171-1                     0.032                      NaN
# 68  1996-04-18   L8327-8                       NaN                      NaN
# 69  1996-04-25  L8368-10                       NaN                      NaN
# 70  1996-05-02  L8425-10                       NaN                      NaN
# 71  1996-05-09  L8552-10                       NaN                      NaN
# 72  1996-05-15   L8466-1                     0.053                      NaN
# 74  1996-05-16  L8590-10                       NaN                      NaN
# 75  1996-05-23  L8685-10                       NaN                      NaN
# 76  1996-05-30  L8709-10                       NaN                      NaN
# 77  1996-06-06  L8782-10                       NaN                      NaN
# 78  1996-06-10   L8747-1                     0.064                      NaN
#
#     Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# 0                       NaN                       170.0
# 2                       NaN                        32.0
# 4                       NaN                        32.0
# 6                       NaN                        44.0
# 8                       NaN                        22.0
# 10                      NaN                       160.0
# 12                      NaN                        44.0
# 14                      NaN                        80.0
# 16                      NaN                        61.0
# 18                      NaN                       220.0
# 20                      NaN                        68.0
# 22                      NaN                        60.0
# 24                      NaN                        81.0
# 26                      NaN                       130.0
# 28                      NaN                       100.0
# 30                      NaN                        11.0
# 32                      NaN                        14.0
# 34                      NaN                        50.0
# 36                      NaN                        35.0
# 38                      NaN                        59.0
# 40                      NaN                        50.0
# 42                      NaN                        62.0
# 44                      NaN                       190.0
# 46                      NaN                      1800.0
# 48                      NaN                       160.0
# 50                      NaN                      5500.0
# 51                      NaN                       100.0
# 52                      NaN                        71.0
# 54                      NaN                        49.0
# 55                      NaN                       140.0
# 56                      NaN                        36.0
# 57                      NaN                        55.0
# 58                      NaN                        66.0
# 60                      NaN                        39.0
# 61                      NaN                        32.0
# 62                      NaN                       330.0
# 63                      NaN                        16.0
# 64                      NaN                        41.0
# 65                      NaN                        41.0
# 66                      NaN                        23.0
# 68                      NaN                        31.0
# 69                      NaN                       380.0
# 70                      NaN                         2.0
# 71                      NaN                         8.0
# 72                      NaN                       160.0
# 74                      NaN                        34.0
# 75                      NaN                       270.0
# 76                      NaN                        24.0
# 77                      NaN                        24.0
# 78                      NaN                         6.0
#
#     Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                    0.190                           0.0090  6.8
# 2                    0.250                           0.0110  7.1
# 4                    0.170                           0.0050  7.3
# 6                    0.119                           0.0020  7.7
# 8                    0.050                           0.0039  8.2
# 10                   0.050                           0.0020  7.5
# 12                   0.050                           0.0044  7.3
# 14                   0.050                           0.0028  7.2
# 16                   0.050                           0.0025  7.6
# 18                   0.050                           0.0167  7.5
# 20                   0.050                           0.0032  7.7
# 22                   0.143                           0.0099  7.4
# 24                   0.210                           0.0170  7.3
# 26                   0.217                           0.0123  7.6
# 28                   0.185                           0.0056  7.6
# 30                   0.050                           0.0025  8.8
# 32                   0.050                           0.0022  9.0
# 34                   0.050                           0.0027  7.9
# 36                   0.050                           0.0026  7.7
# 38                   0.050                           0.0036  7.2
# 40                   0.050                           0.0037  7.6
# 42                   0.050                           0.0098  7.7
# 44                   0.075                           0.0059  7.2
# 46                   0.173                           0.0150  7.3
# 48                   0.225                           0.0150  NaN
# 50                     NaN                              NaN  NaN
# 51                   0.288                           0.0160  7.3
# 52                     NaN                              NaN  NaN
# 54                     NaN                              NaN  NaN
# 55                     NaN                              NaN  NaN
# 56                     NaN                              NaN  NaN
# 57                     NaN                              NaN  NaN
# 58                   0.251                           0.0040  NaN
# 60                     NaN                              NaN  NaN
# 61                     NaN                              NaN  NaN
# 62                     NaN                              NaN  NaN
# 63                     NaN                              NaN  NaN
# 64                     NaN                              NaN  NaN
# 65                     NaN                              NaN  NaN
# 66                   0.092                           0.0020  8.6
# 68                     NaN                              NaN  NaN
# 69                     NaN                              NaN  NaN
# 70                     NaN                              NaN  NaN
# 71                     NaN                              NaN  NaN
# 72                   0.130                           0.0020  7.8
# 74                     NaN                              NaN  NaN
# 75                     NaN                              NaN  NaN
# 76                     NaN                              NaN  NaN
# 77                     NaN                              NaN  NaN
# 78                   0.106                           0.0040  8.1
#
#     Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)
# 0                8.0                  0.340                   0.0210
# 2                6.3                  0.310                   0.0250
# 4                9.0                  0.400                   0.0280
# 6               10.5                  0.337                   0.0190
# 8               15.0                  0.248                   0.0250
# 10              17.2                  0.264                   0.0130
# 12              19.0                  0.282                   0.0108
# 14              21.0                  0.275                   0.0170
# 16              19.1                  0.361                   0.0350
# 18              17.0                  0.361                   0.0350
# 20              11.3                  0.271                   0.0110
# 22               7.2                  0.338                   0.0330
# 24               6.7                  0.364                   0.0390
# 26               5.6                  0.453                   0.0350
# 28               8.3                  0.445                   0.0150
# 30              10.2                  0.379                   0.0250
# 32              13.8                  0.332                   0.0230
# 34              18.2                  0.265                   0.0183
# 36              21.0                  0.238                   0.0220
# 38              19.3                  0.541                   0.0241
# 40              19.4                  0.262                   0.0226
# 42              15.7                  0.315                   0.0247
# 44              11.4                  0.307                   0.0112
# 46               8.8                  0.411                   0.0240
# 48               8.6                  0.433                   0.0260
# 50               NaN                    NaN                      NaN
# 51               7.1                  0.477                   0.0270
# 52               NaN                    NaN                      NaN
# 54               NaN                    NaN                      NaN
# 55               NaN                    NaN                      NaN
# 56               NaN                    NaN                      NaN
# 57               NaN                    NaN                      NaN
# 58               8.2                  0.460                   0.0230
# 60               NaN                    NaN                      NaN
# 61               NaN                    NaN                      NaN
# 62               NaN                    NaN                      NaN
# 63               NaN                    NaN                      NaN
# 64               NaN                    NaN                      NaN
# 65               NaN                    NaN                      NaN
# 66              12.1                  0.452                   0.0170
# 68               NaN                    NaN                      NaN
# 69               NaN                    NaN                      NaN
# 70               NaN                    NaN                      NaN
# 71               NaN                    NaN                      NaN
# 72              12.5                  0.356                   0.0090
# 74               NaN                    NaN                      NaN
# 75               NaN                    NaN                      NaN
# 76               NaN                    NaN                      NaN
# 77               NaN                    NaN                      NaN
# 78              17.0                  0.522                   0.0430

# %%
# Finding out the null values in the remaining columns
print(df_1.shape)
df_1.isnull().sum()
# Out:
# (2180, 12)
# CollectDate                           0
# SampleNum                             0
# Ammmonia Nitrogen (mg/L)           1279
# Conductivity (µmhos/cm)             887
# Dissolved Oxygen (mg/L)             887
# Fecal Coliform (CFU/100ml)         1668
# Nitrate Nitrite (mg/L)             1305
# Orthophosphate Phosphate (mg/L)    1271
# pH                                  853
# Temperature (°C)                    836
# Total Nitrogen (mg/L)              1288
# Total Phosphorus (mg/L)            1169
# dtype: int64

# %%
# Since we have lots of null values we are replacing the null values in each month with the mean of the remaining values in that month.
# Replacing the NaN values:

df_3 = df_1.groupby(["CollectDate"]).apply(lambda x:x.fillna(x.mean()))
df_3.head(5)
# Out:
# C:\Users\gothw\AppData\Local\Temp\ipykernel_27956\1647429865.py:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df_3 = df_1.groupby(["CollectDate"]).apply(lambda x:x.fillna(x.mean()))
# C:\Users\gothw\AppData\Local\Temp\ipykernel_27956\1647429865.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_3 = df_1.groupby(["CollectDate"]).apply(lambda x:x.fillna(x.mean()))
#   CollectDate SampleNum  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0  1994-01-18   L2782-1                     0.020                      NaN
# 2  1994-02-22   L2963-1                     0.042                      NaN
# 4  1994-03-14   L3197-1                     0.020                      NaN
# 6  1994-04-11   L3418-1                     0.020                      NaN
# 8  1994-05-16   L3629-1                     0.020                      NaN
#
#    Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# 0                      NaN                       170.0
# 2                      NaN                        32.0
# 4                      NaN                        32.0
# 6                      NaN                        44.0
# 8                      NaN                        22.0
#
#    Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                   0.190                           0.0090  6.8
# 2                   0.250                           0.0110  7.1
# 4                   0.170                           0.0050  7.3
# 6                   0.119                           0.0020  7.7
# 8                   0.050                           0.0039  8.2
#
#    Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)
# 0               8.0                  0.340                    0.021
# 2               6.3                  0.310                    0.025
# 4               9.0                  0.400                    0.028
# 6              10.5                  0.337                    0.019
# 8              15.0                  0.248                    0.025

# %%
# Removing the SampleNum Column

df_3= df_3.drop(columns=["SampleNum"])

# %%
df_3.isnull().sum()
# Out:
# CollectDate                          0
# Ammmonia Nitrogen (mg/L)           361
# Conductivity (µmhos/cm)            141
# Dissolved Oxygen (mg/L)            141
# Fecal Coliform (CFU/100ml)         332
# Nitrate Nitrite (mg/L)             442
# Orthophosphate Phosphate (mg/L)    349
# pH                                 108
# Temperature (°C)                    88
# Total Nitrogen (mg/L)              360
# Total Phosphorus (mg/L)             60
# dtype: int64

# %%
# Real Water Quality Index Calculation

# Standard values for each parameter/feature, colB
amm_Sn = 0.1
cond_Sn = 300
dis_ox_Sn = 5.5
fec_coli_Sn = 135
nit_nit_Sn = 0.1
orth_phos_Sn = 0.5
pH_Sn = 8.5
temp_Sn = 7
tot_nit_Sn = 1.2
tot_phos_Sn = 0.1

# Inverse of Standard values for each parameter/feature, colC
inv_amm = 1/amm_Sn
inv_cond = 1/cond_Sn
inv_dis_ox = 1/dis_ox_Sn
inv_fec_coli_Sn = 1/fec_coli_Sn
inv_nit_nit = 1/nit_nit_Sn
inv_orth_phos = 1/orth_phos_Sn
inv_pH = 1/pH_Sn
inv_temp = 1/temp_Sn
inv_tot_nit = 1/tot_nit_Sn
inv_tot_phos = 1/tot_phos_Sn

# Sum of all inverses of standard values, colD
sum_all_inv = inv_amm + inv_cond + inv_dis_ox + inv_fec_coli_Sn + inv_nit_nit + inv_orth_phos + inv_pH + inv_temp + inv_tot_nit + inv_tot_phos

# K is the inverse of the sum of all inverses, colE
K = 1/sum_all_inv

# Wn is K divided by the standard value for each parameter/feature, colF
amm_Wn = K / amm_Sn
cond_Wn = K / cond_Sn
dis_ox_Wn = K / dis_ox_Sn
fec_coli_Wn = K / fec_coli_Sn
nit_nit_Wn = K / nit_nit_Sn
orth_phos_Wn = K / orth_phos_Sn
pH_Wn = K / pH_Sn
temp_Wn = K / temp_Sn
tot_nit_Wn = K / tot_nit_Sn
tot_phos_Wn = K / tot_phos_Sn

# Water Quality Index
#test = ((((df_3.loc[0]['Ammmonia Nitrogen (mg/L)']/amm_Sn)*100)*amm_Wn) + (((df_3.loc[0]['Conductivity (µmhos/cm)']/cond_Sn)*100)*cond_Wn)) + (((df_3.loc[0]['Dissolved Oxygen (mg/L)']/dis_ox_Sn)*100)*dis_ox_Wn) + (((df_3.loc[0]['Fecal Coliform (CFU/100ml)']/fec_coli_Sn)*100)*fec_coli_Wn) + (((df_3.loc[0]['Nitrate Nitrite (mg/L)']/nit_nit_Sn)*100)*nit_nit_Wn) + (((df_3.loc[0]['Orthophosphate Phosphate (mg/L)']/orth_phos_Sn)*100)*orth_phos_Wn) + (((df_3.loc[0]['pH']/pH_Sn)*100)*pH_Wn) + (((df_3.loc[0]['Temperature (°C)']/temp_Sn)*100)*temp_Wn) + (((df_3.loc[0]['Total Nitrogen (mg/L)']/tot_nit_Sn)*100)*tot_nit_Wn) + (((df_3.loc[0]['Total Phosphorus (mg/L)']/tot_phos_Sn)*100)*tot_phos_Wn)
#test

df_3['WQI'] = ((((df_3['Ammmonia Nitrogen (mg/L)']/amm_Sn)*100)*amm_Wn) + (((df_3['Conductivity (µmhos/cm)']/cond_Sn)*100)*cond_Wn)) + (((df_3['Dissolved Oxygen (mg/L)']/dis_ox_Sn)*100)*dis_ox_Wn) + (((df_3['Fecal Coliform (CFU/100ml)']/fec_coli_Sn)*100)*fec_coli_Wn) + (((df_3['Nitrate Nitrite (mg/L)']/nit_nit_Sn)*100)*nit_nit_Wn) + (((df_3['Orthophosphate Phosphate (mg/L)']/orth_phos_Sn)*100)*orth_phos_Wn) + (((df_3['pH']/pH_Sn)*100)*pH_Wn) + (((df_3['Temperature (°C)']/temp_Sn)*100)*temp_Wn) + (((df_3['Total Nitrogen (mg/L)']/tot_nit_Sn)*100)*tot_nit_Wn) + (((df_3['Total Phosphorus (mg/L)']/tot_phos_Sn)*100)*tot_phos_Wn)
df_3.head()
# Out:
#   CollectDate  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0  1994-01-18                     0.020                      NaN
# 2  1994-02-22                     0.042                      NaN
# 4  1994-03-14                     0.020                      NaN
# 6  1994-04-11                     0.020                      NaN
# 8  1994-05-16                     0.020                      NaN
#
#    Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# 0                      NaN                       170.0
# 2                      NaN                        32.0
# 4                      NaN                        32.0
# 6                      NaN                        44.0
# 8                      NaN                        22.0
#
#    Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                   0.190                           0.0090  6.8
# 2                   0.250                           0.0110  7.1
# 4                   0.170                           0.0050  7.3
# 6                   0.119                           0.0020  7.7
# 8                   0.050                           0.0039  8.2
#
#    Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  WQI
# 0               8.0                  0.340                    0.021  NaN
# 2               6.3                  0.310                    0.025  NaN
# 4               9.0                  0.400                    0.028  NaN
# 6              10.5                  0.337                    0.019  NaN
# 8              15.0                  0.248                    0.025  NaN

# %%
df_3 = df_3.dropna()
print(df_3.shape)
df_3.count()
# Out:
# (1615, 12)
# CollectDate                        1615
# Ammmonia Nitrogen (mg/L)           1615
# Conductivity (µmhos/cm)            1615
# Dissolved Oxygen (mg/L)            1615
# Fecal Coliform (CFU/100ml)         1615
# Nitrate Nitrite (mg/L)             1615
# Orthophosphate Phosphate (mg/L)    1615
# pH                                 1615
# Temperature (°C)                   1615
# Total Nitrogen (mg/L)              1615
# Total Phosphorus (mg/L)            1615
# WQI                                1615
# dtype: int64

# %%
df_3.head()
# Out:
#     CollectDate  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 108  1997-01-23                     0.024                     99.0
# 109  1997-01-23                     0.021                    101.0
# 111  1997-02-04                     0.027                     87.6
# 112  1997-02-04                     0.028                     93.5
# 114  1997-03-04                     0.020                    116.0
#
#      Dissolved Oxygen (mg/L)  Fecal Coliform (CFU/100ml)  \
# 108                     10.9                       160.0
# 109                     10.8                       160.0
# 111                     10.3                        63.0
# 112                     10.7                        63.0
# 114                     11.3                       160.0
#
#      Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 108                   0.310                           0.0136  7.4
# 109                   0.302                           0.0129  7.3
# 111                   0.328                           0.0134  7.2
# 112                   0.336                           0.0136  7.2
# 114                   0.344                           0.0181  7.5
#
#      Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  \
# 108               6.6                  0.493                   0.0289
# 109               6.6                  0.477                   0.0298
# 111               6.5                  0.452                   0.0236
# 112               6.5                  0.465                   0.0265
# 114               6.8                  0.464                   0.0269
#
#             WQI
# 108  112.040025
# 109  108.949937
# 111  116.578320
# 112  120.222802
# 114  120.502157

# %%
# Create the output file (CSV)


output_data_file = "../Resources_Ritu/0512_lake_Union.csv"

#"../Raw_Water_Quality_Data/Lake Sammamish-0611_1_1_1994_to_9_30_2022.csv"
# Export the clean water quality data 

df_3.to_csv(output_data_file, index="CollectDate")

# %%
print(df_3['CollectDate'].unique().size)
# Out:
# 384
