# %%
# Initial imports
import pandas as pd

# %% [markdown]
# # Import the data

# %%
# Load the water_quality_data.csv dataset for monitoring station 0611.

file_path_1 = "../Project/Water_Quality_Data/Lake Sammamish-0611_1_1_1994_to_9_30_2022.csv"
#df = pd.read_csv(file_path, skiprows=1)[:-2]
WQ_0611_df = pd.read_csv(file_path_1,skiprows=12, encoding='unicode_escape')
WQD_df.head(10)
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0    1/6/1994  L2704-18         1                      0.02
# 1    1/6/1994  L2704-19         5                       NaN
# 2    1/6/1994  L2704-20        10                      0.02
# 3    1/6/1994  L2704-21        15                       NaN
# 4    1/6/1994  L2704-22        20                       NaN
# 5    1/6/1994  L2704-23      22.5                      0.02
# 6    1/6/1994  L2704-18         1                      0.02
# 7   2/14/1994  L2938-18         1                      0.02
# 8   2/14/1994  L2938-19         5                       NaN
# 9   2/14/1994  L2938-20        10                      0.02
#
#   Ammmonia Nitrogen Qualifier* AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                0.02                    103.0
# 1                          NaN           NaN                    104.0
# 2                   <MDL                0.02                    102.0
# 3                          NaN           NaN                    105.0
# 4                          NaN           NaN                    104.0
# 5                   <MDL                0.02                    103.0
# 6                   <MDL                0.02                    103.0
# 7                   <MDL                0.02                    102.5
# 8                          NaN           NaN                    103.9
# 9                   <MDL                0.02                    105.0
#
#   Cond Qualifier*  Cond MDL (µmhos/cm)  Dissolved Oxygen (mg/L)  ...  \
# 0             NaN                  NaN                     9.15  ...
# 1             NaN                  NaN                     8.98  ...
# 2             NaN                  NaN                     9.00  ...
# 3             NaN                  NaN                     9.21  ...
# 4             NaN                  NaN                     9.20  ...
# 5             NaN                  NaN                     9.19  ...
# 6             NaN                  NaN                     9.15  ...
# 7             NaN                  NaN                    10.81  ...
# 8             NaN                  NaN                    10.71  ...
# 9             NaN                  NaN                    10.71  ...
#
#   Temperature Qualifier*  Total Nitrogen (mg/L)  TN Qualifier* TN MDL (mg/L)  \
# 0                    NaN                   0.41            NaN          0.05
# 1                    NaN                    NaN            NaN           NaN
# 2                    NaN                   0.44            NaN          0.05
# 3                    NaN                    NaN            NaN           NaN
# 4                    NaN                    NaN            NaN           NaN
# 5                    NaN                   0.40            NaN          0.05
# 6                    NaN                   0.41            NaN          0.05
# 7                    NaN                   0.47            NaN          0.05
# 8                    NaN                    NaN            NaN           NaN
# 9                    NaN                   0.53            NaN          0.05
#
#    Total Phosphorus (mg/L) TP Qualifier*  TP MDL (mg/L)  \
# 0                    0.017           NaN          0.005
# 1                      NaN           NaN            NaN
# 2                    0.019           NaN          0.005
# 3                      NaN           NaN            NaN
# 4                      NaN           NaN            NaN
# 5                    0.023           NaN          0.005
# 6                    0.017           NaN          0.005
# 7                    0.030           NaN          0.005
# 8                      NaN           NaN            NaN
# 9                    0.049           NaN          0.005
#
#   Total Alkalinity (mg/L) Total Alkalinity Qualifier*  \
# 0                      42                         NaN
# 1                     NaN                         NaN
# 2                      42                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
# 5                      42                         NaN
# 6                      42                         NaN
# 7                     NaN                         NaN
# 8                     NaN                         NaN
# 9                     NaN                         NaN
#
#    Total Alkalinity MDL (mg/L)
# 0                          0.2
# 1                          NaN
# 2                          0.2
# 3                          NaN
# 4                          NaN
# 5                          0.2
# 6                          0.2
# 7                          NaN
# 8                          NaN
# 9                          NaN
#
# [10 rows x 35 columns]

# %%
WQ_0611_df.count()
# Out:
# CollectDate                        10039
# SampleNum                          10039
# Depth (m)                          10016
# Ammmonia Nitrogen (mg/L)            2544
# Ammmonia Nitrogen Qualifier*        2205
# AN MDL (mg/L)                       2659
# Conductivity (µmhos/cm)             8135
# Cond Qualifier*                      445
# Cond MDL (µmhos/cm)                 6020
# Dissolved Oxygen (mg/L)             8052
# DO Qualifier*                        809
# DO MDL (mg/L)                       6014
# Ecoli                                170
# Ecoli Qualifier*                       5
# Fecal Coliform (CFU/100ml)           316
# Fecal Coliform Qualifier*              3
# Nitrate Nitrite (mg/L)              2570
# Nitrate Nitrite Qualifier*           581
# Nitrate Nitrite MDL (mg/L)          2660
# Orthophosphate Phosphate (mg/L)     2479
# OP Qualifier*                       1796
# OP MDL (mg/L)                       2657
# pH                                  8145
# pH Qualifier*                        435
# Temperature (°C)                    8155
# Temperature Qualifier*               433
# Total Nitrogen (mg/L)               2647
# TN Qualifier*                        140
# TN MDL (mg/L)                       2649
# Total Phosphorus (mg/L)             2750
# TP Qualifier*                       1066
# TP MDL (mg/L)                       2769
# Total Alkalinity (mg/L)              390
# Total Alkalinity Qualifier*            6
# Total Alkalinity MDL (mg/L)          388
# dtype: int64

# %%
# Dropping the columns which are not very useful for the analysis. 
# df.drop(['col1','col2','col5','colN'], axis=1, inplace=True) 

WQ_0611_df = WQ_0611_df.drop(columns=["Depth (m)", "Ammmonia Nitrogen Qualifier*", "Cond Qualifier*", "DO Qualifier*", 
                                "Ecoli Qualifier*", "Fecal Coliform Qualifier*","Nitrate Nitrite Qualifier*", "OP Qualifier*", 
                                "pH Qualifier*","Temperature Qualifier*", "TN Qualifier*", "TN Qualifier*","TP Qualifier*", "Total Alkalinity Qualifier*" ])

# Dropping the columns with heading MDL in it as it is just reporting the minimum detection limit of the method, which is not actually usefull for this analysis.
WQ_0611_df= WQ_0611_df.drop(columns=["AN MDL (mg/L)", "Cond MDL (µmhos/cm)", "DO MDL (mg/L)", "Nitrate Nitrite MDL (mg/L)",
                                  "OP MDL (mg/L)", "TN MDL (mg/L)", "TP MDL (mg/L)", "Total Alkalinity MDL (mg/L)" ])


WQ_0611_df.head()
# Out:
#   CollectDate SampleNum  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0    1/6/1994  L2704-18                      0.02                    103.0
# 1    1/6/1994  L2704-19                       NaN                    104.0
# 2    1/6/1994  L2704-20                      0.02                    102.0
# 3    1/6/1994  L2704-21                       NaN                    105.0
# 4    1/6/1994  L2704-22                       NaN                    104.0
#
#    Dissolved Oxygen (mg/L)  Ecoli  Fecal Coliform (CFU/100ml)  \
# 0                     9.15    NaN                         1.0
# 1                     8.98    NaN                         NaN
# 2                     9.00    NaN                         NaN
# 3                     9.21    NaN                         NaN
# 4                     9.20    NaN                         NaN
#
#    Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                    0.27                            0.011  7.4
# 1                     NaN                              NaN  7.4
# 2                    0.29                            0.012  7.4
# 3                     NaN                              NaN  7.4
# 4                     NaN                              NaN  7.4
#
#    Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  \
# 0               7.4                   0.41                    0.017
# 1               7.3                    NaN                      NaN
# 2               7.3                   0.44                    0.019
# 3               7.3                    NaN                      NaN
# 4               7.3                    NaN                      NaN
#
#   Total Alkalinity (mg/L)
# 0                      42
# 1                     NaN
# 2                      42
# 3                     NaN
# 4                     NaN

# %%
WQ_0611_df.count()
# Out:
# CollectDate                        10039
# SampleNum                          10039
# Ammmonia Nitrogen (mg/L)            2544
# Conductivity (µmhos/cm)             8135
# Dissolved Oxygen (mg/L)             8052
# Ecoli                                170
# Fecal Coliform (CFU/100ml)           316
# Nitrate Nitrite (mg/L)              2570
# Orthophosphate Phosphate (mg/L)     2479
# pH                                  8145
# Temperature (°C)                    8155
# Total Nitrogen (mg/L)               2647
# Total Phosphorus (mg/L)             2750
# Total Alkalinity (mg/L)              390
# dtype: int64

# %%
WQ_0611_df.isnull().sum()
# Out:
# CollectDate                           0
# SampleNum                             0
# Ammmonia Nitrogen (mg/L)           7495
# Conductivity (µmhos/cm)            1904
# Dissolved Oxygen (mg/L)            1987
# Ecoli                              9869
# Fecal Coliform (CFU/100ml)         9723
# Nitrate Nitrite (mg/L)             7469
# Orthophosphate Phosphate (mg/L)    7560
# pH                                 1894
# Temperature (°C)                   1884
# Total Nitrogen (mg/L)              7392
# Total Phosphorus (mg/L)            7289
# Total Alkalinity (mg/L)            9649
# dtype: int64

# %%
WQ_0611_df_1= WQ_0611_df.drop(columns=["Ecoli","Fecal Coliform (CFU/100ml)", "Total Alkalinity (mg/L)"])

WQ_0611_df_1.head(50)
# Out:
#    CollectDate SampleNum  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0     1/6/1994  L2704-18                      0.02                    103.0
# 1     1/6/1994  L2704-19                       NaN                    104.0
# 2     1/6/1994  L2704-20                      0.02                    102.0
# 3     1/6/1994  L2704-21                       NaN                    105.0
# 4     1/6/1994  L2704-22                       NaN                    104.0
# 5     1/6/1994  L2704-23                      0.02                    103.0
# 6     1/6/1994  L2704-18                      0.02                    103.0
# 7    2/14/1994  L2938-18                      0.02                    102.5
# 8    2/14/1994  L2938-19                       NaN                    103.9
# 9    2/14/1994  L2938-20                      0.02                    105.0
# 10   2/14/1994  L2938-21                       NaN                    105.2
# 11   2/14/1994  L2938-22                       NaN                    105.2
# 12   2/14/1994  L2938-23                      0.02                    105.5
# 13   2/14/1994  L2938-18                      0.02                    102.5
# 14    3/8/1994  L3136-18                      0.02                    103.4
# 15    3/8/1994  L3136-19                       NaN                    104.0
# 16    3/8/1994  L3136-20                      0.02                    105.1
# 17    3/8/1994  L3136-21                       NaN                    105.3
# 18    3/8/1994  L3136-22                       NaN                    105.9
# 19    3/8/1994  L3136-23                      0.02                    105.3
# 20    3/8/1994  L3136-18                      0.02                    103.4
# 21   3/22/1994  L3278-18                      0.02                    104.0
# 22   3/22/1994  L3278-19                       NaN                    105.3
# 23   3/22/1994  L3278-20                      0.02                    105.9
# 24   3/22/1994  L3278-21                       NaN                    106.2
# 25   3/22/1994  L3278-22                       NaN                    106.3
# 26   3/22/1994  L3278-23                       NaN                    106.5
# 27   3/22/1994  L3278-18                      0.02                    104.0
# 28    4/5/1994  L3378-18                      0.02                    103.7
# 29    4/5/1994  L3378-19                       NaN                    104.2
# 30    4/5/1994  L3378-20                      0.02                    103.3
# 31    4/5/1994  L3378-21                       NaN                    103.3
# 32    4/5/1994  L3378-22                       NaN                    103.7
# 33    4/5/1994  L3378-23                      0.02                    103.9
# 34    4/5/1994  L3378-18                      0.02                    103.7
# 35   4/19/1994  L3514-18                      0.02                    104.5
# 36   4/19/1994  L3514-19                       NaN                    105.0
# 37   4/19/1994  L3514-20                      0.02                    103.9
# 38   4/19/1994  L3514-21                       NaN                    103.6
# 39   4/19/1994  L3514-22                       NaN                    104.1
# 40   4/19/1994  L3514-23                      0.02                    104.1
# 41   4/19/1994  L3514-18                      0.02                    104.5
# 42    5/3/1994  L3610-18                      0.02                    108.3
# 43    5/3/1994  L3610-19                       NaN                    108.5
# 44    5/3/1994  L3610-20                      0.02                    107.0
# 45    5/3/1994  L3610-21                       NaN                    106.6
# 46    5/3/1994  L3610-22                       NaN                    106.3
# 47    5/3/1994  L3610-23                      0.02                    106.4
# 48    5/3/1994  L3610-18                      0.02                    108.3
# 49   5/24/1994  L3772-18                      0.02                    114.1
#
#     Dissolved Oxygen (mg/L)  Nitrate Nitrite (mg/L)  \
# 0                      9.15                   0.270
# 1                      8.98                     NaN
# 2                      9.00                   0.290
# 3                      9.21                     NaN
# 4                      9.20                     NaN
# 5                      9.19                   0.280
# 6                      9.15                   0.270
# 7                     10.81                   0.310
# 8                     10.71                     NaN
# 9                     10.71                   0.260
# 10                    10.65                     NaN
# 11                    10.62                     NaN
# 12                    10.62                   0.320
# 13                    10.81                   0.310
# 14                    11.50                   0.280
# 15                    11.06                     NaN
# 16                    10.97                   0.380
# 17                    10.80                     NaN
# 18                    10.14                     NaN
# 19                     9.69                   0.320
# 20                    11.50                   0.280
# 21                    12.63                   0.290
# 22                    12.24                     NaN
# 23                    11.91                   0.310
# 24                    11.76                     NaN
# 25                    11.71                     NaN
# 26                    11.70                     NaN
# 27                    12.63                   0.290
# 28                    15.04                   0.223
# 29                    15.01                     NaN
# 30                    13.28                   0.276
# 31                    11.83                     NaN
# 32                    11.13                     NaN
# 33                     9.59                   0.360
# 34                    15.04                   0.223
# 35                    12.89                   0.241
# 36                    12.89                     NaN
# 37                    13.65                   0.252
# 38                    12.52                     NaN
# 39                    11.35                     NaN
# 40                     9.31                   0.341
# 41                    12.89                   0.241
# 42                    10.84                   0.251
# 43                    10.53                     NaN
# 44                    12.69                   0.276
# 45                    11.29                     NaN
# 46                     8.51                     NaN
# 47                     8.31                   0.326
# 48                    10.84                   0.251
# 49                    10.21                   0.264
#
#     Orthophosphate Phosphate (mg/L)   pH  Temperature (°C)  \
# 0                            0.0110  7.4               7.4
# 1                               NaN  7.4               7.3
# 2                            0.0120  7.4               7.3
# 3                               NaN  7.4               7.3
# 4                               NaN  7.4               7.3
# 5                            0.0130  7.4               7.3
# 6                            0.0110  7.4               7.4
# 7                            0.0090  7.4               6.5
# 8                               NaN  7.4               6.5
# 9                            0.0090  7.4               6.5
# 10                              NaN  7.4               6.5
# 11                              NaN  7.4               6.5
# 12                           0.0090  7.4               6.5
# 13                           0.0090  7.4               6.5
# 14                           0.0030  7.8               7.5
# 15                              NaN  7.6               7.1
# 16                           0.0030  7.6               7.1
# 17                              NaN  7.5               6.9
# 18                              NaN  7.4               6.7
# 19                           0.0090  7.3               6.5
# 20                           0.0030  7.8               7.5
# 21                           0.0020  8.7               8.0
# 22                              NaN  8.3               7.6
# 23                           0.0020  8.1               7.6
# 24                              NaN  8.1               7.5
# 25                              NaN  8.1               7.5
# 26                              NaN  8.1               7.5
# 27                           0.0020  8.7               8.0
# 28                           0.0047  9.4              10.3
# 29                              NaN  9.3              10.0
# 30                           0.0047  8.7               7.9
# 31                              NaN  7.9               7.4
# 32                              NaN  7.7               7.2
# 33                           0.0047  7.4               7.1
# 34                           0.0047  9.4              10.3
# 35                           0.0020  9.2              12.6
# 36                              NaN  9.2              12.5
# 37                           0.0020  9.2               9.5
# 38                              NaN  8.7               8.7
# 39                              NaN    8               8.0
# 40                           0.0020  7.5               7.5
# 41                           0.0020  9.2              12.6
# 42                           0.0020  8.8              13.8
# 43                              NaN  8.8              13.4
# 44                           0.0020  8.7               9.4
# 45                              NaN  7.9               8.2
# 46                              NaN  7.2               7.7
# 47                           0.0020  7.1               7.6
# 48                           0.0020  8.8              13.8
# 49                           0.0020  8.4              17.7
#
#     Total Nitrogen (mg/L)  Total Phosphorus (mg/L)
# 0                   0.410                    0.017
# 1                     NaN                      NaN
# 2                   0.440                    0.019
# 3                     NaN                      NaN
# 4                     NaN                      NaN
# 5                   0.400                    0.023
# 6                   0.410                    0.017
# 7                   0.470                    0.030
# 8                     NaN                      NaN
# 9                   0.530                    0.049
# 10                    NaN                      NaN
# 11                    NaN                      NaN
# 12                  0.500                    0.029
# 13                  0.470                    0.030
# 14                  0.530                    0.013
# 15                    NaN                      NaN
# 16                  0.550                    0.013
# 17                    NaN                      NaN
# 18                    NaN                      NaN
# 19                  0.540                    0.015
# 20                  0.530                    0.013
# 21                  0.500                    0.016
# 22                    NaN                      NaN
# 23                  0.530                    0.014
# 24                    NaN                      NaN
# 25                    NaN                      NaN
# 26                    NaN                      NaN
# 27                  0.500                    0.016
# 28                  0.439                    0.009
# 29                    NaN                      NaN
# 30                  0.454                    0.009
# 31                    NaN                      NaN
# 32                    NaN                      NaN
# 33                  0.525                    0.013
# 34                  0.439                    0.009
# 35                  0.427                    0.011
# 36                    NaN                      NaN
# 37                  0.469                    0.018
# 38                    NaN                      NaN
# 39                    NaN                      NaN
# 40                  0.527                    0.013
# 41                  0.427                    0.011
# 42                  0.416                    0.008
# 43                    NaN                      NaN
# 44                  0.454                    0.008
# 45                    NaN                      NaN
# 46                    NaN                      NaN
# 47                  0.510                    0.012
# 48                  0.416                    0.008
# 49                  0.428                    0.015

# %%
WQ_0611_df_1.count()

# %%
WQ_0611_df_1 = WQ_0611_df.dropna()
WQ_0611_df_1.count()
# Out:
# CollectDate                        39
# SampleNum                          39
# Ammmonia Nitrogen (mg/L)           39
# Conductivity (µmhos/cm)            39
# Dissolved Oxygen (mg/L)            39
# Ecoli                              39
# Fecal Coliform (CFU/100ml)         39
# Nitrate Nitrite (mg/L)             39
# Orthophosphate Phosphate (mg/L)    39
# pH                                 39
# Temperature (°C)                   39
# Total Nitrogen (mg/L)              39
# Total Phosphorus (mg/L)            39
# Total Alkalinity (mg/L)            39
# dtype: int64

# %% [markdown]
# # Importing another csv file for monitoring station 0612

# %%
# Load the water_quality_data.csv dataset for monitoring station 0612.


file_path_2 = "../Project/Water_Quality_Data/Lake Sammamish-0612_1_1_1994_to_9_30_2022.csv"
#df = pd.read_csv(file_path, skiprows=1)[:-2]
WQ_0612_df = pd.read_csv(file_path_2,skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

WQD_df.head(10)
# Out:
# C:\Users\gothw\AppData\Local\Temp\ipykernel_61104\2042564184.py:6: DtypeWarning: Columns (2,7,13,15,23,25,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   WQ_0612_df = pd.read_csv(file_path_2,skiprows=12, encoding='unicode_escape', on_bad_lines='skip')
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0    1/6/1994  L2704-18         1                      0.02
# 1    1/6/1994  L2704-19         5                       NaN
# 2    1/6/1994  L2704-20        10                      0.02
# 3    1/6/1994  L2704-21        15                       NaN
# 4    1/6/1994  L2704-22        20                       NaN
# 5    1/6/1994  L2704-23      22.5                      0.02
# 6    1/6/1994  L2704-18         1                      0.02
# 7   2/14/1994  L2938-18         1                      0.02
# 8   2/14/1994  L2938-19         5                       NaN
# 9   2/14/1994  L2938-20        10                      0.02
#
#   Ammmonia Nitrogen Qualifier* AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                0.02                    103.0
# 1                          NaN           NaN                    104.0
# 2                   <MDL                0.02                    102.0
# 3                          NaN           NaN                    105.0
# 4                          NaN           NaN                    104.0
# 5                   <MDL                0.02                    103.0
# 6                   <MDL                0.02                    103.0
# 7                   <MDL                0.02                    102.5
# 8                          NaN           NaN                    103.9
# 9                   <MDL                0.02                    105.0
#
#   Cond Qualifier*  Cond MDL (µmhos/cm)  Dissolved Oxygen (mg/L)  ...  \
# 0             NaN                  NaN                     9.15  ...
# 1             NaN                  NaN                     8.98  ...
# 2             NaN                  NaN                     9.00  ...
# 3             NaN                  NaN                     9.21  ...
# 4             NaN                  NaN                     9.20  ...
# 5             NaN                  NaN                     9.19  ...
# 6             NaN                  NaN                     9.15  ...
# 7             NaN                  NaN                    10.81  ...
# 8             NaN                  NaN                    10.71  ...
# 9             NaN                  NaN                    10.71  ...
#
#   Temperature Qualifier*  Total Nitrogen (mg/L)  TN Qualifier* TN MDL (mg/L)  \
# 0                    NaN                   0.41            NaN          0.05
# 1                    NaN                    NaN            NaN           NaN
# 2                    NaN                   0.44            NaN          0.05
# 3                    NaN                    NaN            NaN           NaN
# 4                    NaN                    NaN            NaN           NaN
# 5                    NaN                   0.40            NaN          0.05
# 6                    NaN                   0.41            NaN          0.05
# 7                    NaN                   0.47            NaN          0.05
# 8                    NaN                    NaN            NaN           NaN
# 9                    NaN                   0.53            NaN          0.05
#
#    Total Phosphorus (mg/L) TP Qualifier*  TP MDL (mg/L)  \
# 0                    0.017           NaN          0.005
# 1                      NaN           NaN            NaN
# 2                    0.019           NaN          0.005
# 3                      NaN           NaN            NaN
# 4                      NaN           NaN            NaN
# 5                    0.023           NaN          0.005
# 6                    0.017           NaN          0.005
# 7                    0.030           NaN          0.005
# 8                      NaN           NaN            NaN
# 9                    0.049           NaN          0.005
#
#   Total Alkalinity (mg/L) Total Alkalinity Qualifier*  \
# 0                      42                         NaN
# 1                     NaN                         NaN
# 2                      42                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
# 5                      42                         NaN
# 6                      42                         NaN
# 7                     NaN                         NaN
# 8                     NaN                         NaN
# 9                     NaN                         NaN
#
#    Total Alkalinity MDL (mg/L)
# 0                          0.2
# 1                          NaN
# 2                          0.2
# 3                          NaN
# 4                          NaN
# 5                          0.2
# 6                          0.2
# 7                          NaN
# 8                          NaN
# 9                          NaN
#
# [10 rows x 35 columns]

# %%
WQ_0612_df.count()
# Out:
# CollectDate                        19896
# SampleNum                          19896
# Depth (m)                          19875
# Ammmonia Nitrogen (mg/L)            2717
# Ammmonia Nitrogen Qualifier*        2357
# AN MDL (mg/L)                       2866
# Conductivity (µmhos/cm)            17764
# Cond Qualifier*                      993
# Cond MDL (µmhos/cm)                15546
# Dissolved Oxygen (mg/L)            17473
# DO Qualifier*                       2576
# DO MDL (mg/L)                      15532
# Ecoli                                172
# Ecoli Qualifier*                       4
# Fecal Coliform (CFU/100ml)           317
# Fecal Coliform Qualifier*              2
# Nitrate Nitrite (mg/L)              2780
# Nitrate Nitrite Qualifier*           558
# Nitrate Nitrite MDL (mg/L)          2866
# Orthophosphate Phosphate (mg/L)     2708
# OP Qualifier*                       1859
# OP MDL (mg/L)                       2863
# pH                                 17768
# pH Qualifier*                        982
# Temperature (°C)                   17783
# Temperature Qualifier*               982
# Total Nitrogen (mg/L)               2862
# TN Qualifier*                        136
# TN MDL (mg/L)                       2862
# Total Phosphorus (mg/L)             2971
# TP Qualifier*                       1140
# TP MDL (mg/L)                       2987
# Total Alkalinity (mg/L)             1997
# Total Alkalinity Qualifier*           22
# Total Alkalinity MDL (mg/L)         2001
# Unnamed: 35                            0
# dtype: int64

# %%
# Dropping the columns which are not very useful for the analysis. 
# df.drop(['col1','col2','col5','colN'], axis=1, inplace=True) 

WQ_0612_df = WQ_0612_df.drop(columns=["Depth (m)", "Ammmonia Nitrogen Qualifier*", "Cond Qualifier*", "DO Qualifier*", 
                                "Ecoli Qualifier*", "Fecal Coliform Qualifier*","Nitrate Nitrite Qualifier*", "OP Qualifier*", 
                                "pH Qualifier*","Temperature Qualifier*", "TN Qualifier*", "TN Qualifier*","TP Qualifier*", "Total Alkalinity Qualifier*" ])

# Dropping the columns with heading MDL in it as it is just reporting the minimum detection limit of the method, which is not actually usefull for this analysis.
WQ_0612_df= WQ_0612_df.drop(columns=["AN MDL (mg/L)", "Cond MDL (µmhos/cm)", "DO MDL (mg/L)", "Nitrate Nitrite MDL (mg/L)",
                                  "OP MDL (mg/L)", "TN MDL (mg/L)", "TP MDL (mg/L)", "Total Alkalinity MDL (mg/L)","Unnamed: 35" ])


WQ_0612_df.head()
# Out:
#   CollectDate SampleNum  Ammmonia Nitrogen (mg/L)  Conductivity (µmhos/cm)  \
# 0  01/06/1994   L2704-5                      0.02                    102.0
# 1  01/06/1994   L2704-6                       NaN                    105.0
# 2  01/06/1994   L2704-7                      0.02                    104.0
# 3  01/06/1994   L2704-8                       NaN                    104.0
# 4  01/06/1994   L2704-9                       NaN                    103.0
#
#    Dissolved Oxygen (mg/L)  Ecoli  Fecal Coliform (CFU/100ml)  \
# 0                     9.17    NaN                         2.0
# 1                     8.88    NaN                         NaN
# 2                     9.25    NaN                         NaN
# 3                     9.22    NaN                         NaN
# 4                     9.21    NaN                         NaN
#
#    Nitrate Nitrite (mg/L)  Orthophosphate Phosphate (mg/L)   pH  \
# 0                    0.29                            0.011  7.4
# 1                     NaN                              NaN  7.4
# 2                    0.26                            0.009  7.4
# 3                     NaN                              NaN  7.4
# 4                     NaN                              NaN  7.4
#
#    Temperature (°C)  Total Nitrogen (mg/L)  Total Phosphorus (mg/L)  \
# 0               7.4                   0.39                    0.020
# 1               7.3                    NaN                      NaN
# 2               7.3                   0.47                    0.026
# 3               7.3                    NaN                      NaN
# 4               7.3                    NaN                      NaN
#
#    Total Alkalinity (mg/L)
# 0                     42.0
# 1                      NaN
# 2                     42.0
# 3                      NaN
# 4                      NaN

# %%
WQ_0612_df.count()
# Out:
# CollectDate                        19896
# SampleNum                          19896
# Ammmonia Nitrogen (mg/L)            2717
# Conductivity (µmhos/cm)            17764
# Dissolved Oxygen (mg/L)            17473
# Ecoli                                172
# Fecal Coliform (CFU/100ml)           317
# Nitrate Nitrite (mg/L)              2780
# Orthophosphate Phosphate (mg/L)     2708
# pH                                 17768
# Temperature (°C)                   17783
# Total Nitrogen (mg/L)               2862
# Total Phosphorus (mg/L)             2971
# Total Alkalinity (mg/L)             1997
# dtype: int64
