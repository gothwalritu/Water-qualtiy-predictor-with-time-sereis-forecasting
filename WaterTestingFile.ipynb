# %%
# Import descrepancies
import pandas as pd 
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load the file data into the path
file_path_01 = "/Users/linghoang/UCBBootcamp/DataClass/GroupProject/Resources/Lake_Sammamish_0611.csv"

# Load the file_path data into dataframe
WQ0611_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

# Show the WQ dataframe 
WQ0611_df.head(10)
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994  L2704-18       1.0                      0.02
# 1  01/06/1994  L2704-19       5.0                       NaN
# 2  01/06/1994  L2704-20      10.0                      0.02
# 3  01/06/1994  L2704-21      15.0                       NaN
# 4  01/06/1994  L2704-22      20.0                       NaN
# 5  01/06/1994  L2704-23      22.5                      0.02
# 6  01/06/1994  L2704-18       1.0                      0.02
# 7  02/14/1994  L2938-18       1.0                      0.02
# 8  02/14/1994  L2938-19       5.0                       NaN
# 9  02/14/1994  L2938-20      10.0                      0.02
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                 0.02                    103.0
# 1                          NaN            NaN                    104.0
# 2                   <MDL                 0.02                    102.0
# ...

# %%
# Load the file data into the path
file_path_02 = "/Users/linghoang/UCBBootcamp/DataClass/GroupProject/Resources/Lake_Sammamish_0614.csv"

# Load the file_path data into dataframe
WQ0614_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

# Show the WQ dataframe 
WQ0614_df.head(20)
# Out:
#    CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0   01/06/1994  L2704-18       1.0                      0.02
# 1   01/06/1994  L2704-19       5.0                       NaN
# 2   01/06/1994  L2704-20      10.0                      0.02
# 3   01/06/1994  L2704-21      15.0                       NaN
# 4   01/06/1994  L2704-22      20.0                       NaN
# 5   01/06/1994  L2704-23      22.5                      0.02
# 6   01/06/1994  L2704-18       1.0                      0.02
# 7   02/14/1994  L2938-18       1.0                      0.02
# 8   02/14/1994  L2938-19       5.0                       NaN
# 9   02/14/1994  L2938-20      10.0                      0.02
# 10  02/14/1994  L2938-21      15.0                       NaN
# 11  02/14/1994  L2938-22      20.0                       NaN
# 12  02/14/1994  L2938-23      22.0                      0.02
# 13  02/14/1994  L2938-18       1.0                      0.02
# ...

# %%
# Load the file data into the path
file_path_03 = "/Users/linghoang/UCBBootcamp/DataClass/GroupProject/Resources/Lake_Sammamish_0617.csv"

# Load the file_path data into dataframe
WQ0617_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

# Show the WQ dataframe 
WQ0617_df.head(10)
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994  L2704-18       1.0                      0.02
# 1  01/06/1994  L2704-19       5.0                       NaN
# 2  01/06/1994  L2704-20      10.0                      0.02
# 3  01/06/1994  L2704-21      15.0                       NaN
# 4  01/06/1994  L2704-22      20.0                       NaN
# 5  01/06/1994  L2704-23      22.5                      0.02
# 6  01/06/1994  L2704-18       1.0                      0.02
# 7  02/14/1994  L2938-18       1.0                      0.02
# 8  02/14/1994  L2938-19       5.0                       NaN
# 9  02/14/1994  L2938-20      10.0                      0.02
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                 0.02                    103.0
# 1                          NaN            NaN                    104.0
# 2                   <MDL                 0.02                    102.0
# ...

# %%
# Load the file data into the path
file_path_04 = "/Users/linghoang/UCBBootcamp/DataClass/GroupProject/Resources/Lake_Sammamish_0622.csv"

# Load the file_path data into dataframe
WQ0622_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

# Show the WQ dataframe 
WQ0622_df.head(10)
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994  L2704-18       1.0                      0.02
# 1  01/06/1994  L2704-19       5.0                       NaN
# 2  01/06/1994  L2704-20      10.0                      0.02
# 3  01/06/1994  L2704-21      15.0                       NaN
# 4  01/06/1994  L2704-22      20.0                       NaN
# 5  01/06/1994  L2704-23      22.5                      0.02
# 6  01/06/1994  L2704-18       1.0                      0.02
# 7  02/14/1994  L2938-18       1.0                      0.02
# 8  02/14/1994  L2938-19       5.0                       NaN
# 9  02/14/1994  L2938-20      10.0                      0.02
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                 0.02                    103.0
# 1                          NaN            NaN                    104.0
# 2                   <MDL                 0.02                    102.0
# ...

# %%
# Load the file data into the path
file_path_04 = "/Users/linghoang/UCBBootcamp/DataClass/GroupProject/Resources/Lake_Sammamish_0625.csv"

# Load the file_path data into dataframe
WQ0625_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

# Show the WQ dataframe 
WQ0625_df.head(10)
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994  L2704-18       1.0                      0.02
# 1  01/06/1994  L2704-19       5.0                       NaN
# 2  01/06/1994  L2704-20      10.0                      0.02
# 3  01/06/1994  L2704-21      15.0                       NaN
# 4  01/06/1994  L2704-22      20.0                       NaN
# 5  01/06/1994  L2704-23      22.5                      0.02
# 6  01/06/1994  L2704-18       1.0                      0.02
# 7  02/14/1994  L2938-18       1.0                      0.02
# 8  02/14/1994  L2938-19       5.0                       NaN
# 9  02/14/1994  L2938-20      10.0                      0.02
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                 0.02                    103.0
# 1                          NaN            NaN                    104.0
# 2                   <MDL                 0.02                    102.0
# ...

# %%
# Load the file data into the path
file_path_05 = "/Users/linghoang/UCBBootcamp/DataClass/GroupProject/Resources/Lake_Sammamish_M621.csv"

# Load the file_path data into dataframe
WQM621_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

# Show the WQ dataframe 
WQM621_df.head(10)
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994  L2704-18       1.0                      0.02
# 1  01/06/1994  L2704-19       5.0                       NaN
# 2  01/06/1994  L2704-20      10.0                      0.02
# 3  01/06/1994  L2704-21      15.0                       NaN
# 4  01/06/1994  L2704-22      20.0                       NaN
# 5  01/06/1994  L2704-23      22.5                      0.02
# 6  01/06/1994  L2704-18       1.0                      0.02
# 7  02/14/1994  L2938-18       1.0                      0.02
# 8  02/14/1994  L2938-19       5.0                       NaN
# 9  02/14/1994  L2938-20      10.0                      0.02
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                 0.02                    103.0
# 1                          NaN            NaN                    104.0
# 2                   <MDL                 0.02                    102.0
# ...

# %%
# Load the file data into the path
file_path_04 = "/Users/linghoang/UCBBootcamp/DataClass/GroupProject/Resources/Lake_Sammamish_0622.csv"

# Load the file_path data into dataframe
WQ0622_df = pd.read_csv(file_path, skiprows=12, encoding='unicode_escape', on_bad_lines='skip')

# Show the WQ dataframe 
WQ0622_df.head(10)
# Out:
#   CollectDate SampleNum Depth (m)  Ammmonia Nitrogen (mg/L)  \
# 0  01/06/1994  L2704-18       1.0                      0.02
# 1  01/06/1994  L2704-19       5.0                       NaN
# 2  01/06/1994  L2704-20      10.0                      0.02
# 3  01/06/1994  L2704-21      15.0                       NaN
# 4  01/06/1994  L2704-22      20.0                       NaN
# 5  01/06/1994  L2704-23      22.5                      0.02
# 6  01/06/1994  L2704-18       1.0                      0.02
# 7  02/14/1994  L2938-18       1.0                      0.02
# 8  02/14/1994  L2938-19       5.0                       NaN
# 9  02/14/1994  L2938-20      10.0                      0.02
#
#   Ammmonia Nitrogen Qualifier*  AN MDL (mg/L)  Conductivity (µmhos/cm)  \
# 0                   <MDL                 0.02                    103.0
# 1                          NaN            NaN                    104.0
# 2                   <MDL                 0.02                    102.0
# ...
